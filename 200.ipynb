# %%
import matplotlib.pyplot as plt
import sys

# %%
# !{sys.executable} ../kbencoder.py --generate_kb --num_rules 200 --new_vocab --save_vocab
# Out:
# Classes: 100000000000.0
# Max arity: 5
# KB generated (200)

# %%
# !{sys.executable} ../kbencoder.py --kb_path randomKB.txt --train_unification_model
# Out:
# Using cuda device
# Uni model embed size: 50
#  [████████████████████] 3500/3500 Anchors generated
#  [████████████████████] 70000/70000 Triplets generated
#  [█████---------------] 18239/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [████████████--------] 42373/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [███████████████████-] 67468/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Early stopping triggered-------------] 17.8% Epoch | [Epoch 90/500, Training Loss: 0.2530, Validation Loss: 0.5321]
# Saved model.
# Saved plot.
# unification model generated

# %%
import glob
glob.glob('training_loss*.png')
# Out:
# ['training_loss-10-100-5-50.png']

# %%
img = plt.imread('training_loss-10-100-5-50.png')
plt. imshow(img)

# %%
import sys
# !{sys.executable} ../kbencoder.py --kb_path randomKB.txt -g
# Out:
# Generating facts list...
# Forward chaining depth: 1
# New facts: 108
# Forward chaining depth: 2
# New facts: 66
# Forward chaining depth: 3
# New facts: 13
# Forward chaining depth: 4
# New facts: 7
# Forward chaining depth: 5
# New facts: 4
# Forward chaining depth: 6
#
# Facts list generated
# 198 total facts. Max depth = 5
#
# Number of queries: 200
# 100 training queries generated
# 100 testing queries generated

# %%
# !{sys.executable} ../kbencoder.py --kb_path randomKB.txt -p
# Out:
# running training queries...
# Negative facts will be generated
# 1: [p7(X0, X0)]
# Restart...
# min depth: 2
# Nodes: 100049
# Answers: 790
#
# 2: [p0(X6)]
# min depth: 1
# Nodes: 100064
# Answers: 576
#
# 3: [p0(X0), p7(X0, X0), p6(X0)]
# min depth: 1
# Nodes: 100060
# Answers: 669
#
# 4: [p7(X0, X0), p7(X0, X0), p4(a11, X0, a11, X0, X1), p4(a14, a20, a14, a20, X1)]
# min depth: 2
# Nodes: 100082
# Answers: 632
#
# 5: [p7(X7, a72)]
# Nodes: 100102
# Answers: 1
#
# 6: [p7(X0, X0), p1(X0), p7(X0, X0), p3(X0, a28)]
# min depth: 3
# Nodes: 100065
# Answers: 166
#
# 7: [p4(X7, X5, X7, X5, X1)]
# min depth: 2
# Nodes: 10064
# Answers: 16
#
# 8: [p7(X9, a0)]
# min depth: 1
# Nodes: 100019
# Answers: 230
#
# 9: [p0(X8)]
# min depth: 2
# Nodes: 100104
# Answers: 935
#
# 10: [p7(X9, X9)]
# Restart...
# min depth: 2
# Nodes: 73106
# Answers: 1000
#
# 11: [p7(X5, X5)]
# Restart...
# Restart...
# min depth: 3
# Nodes: 100009
# Answers: 250
#
# 12: [p9(X1, X1, a28)]
# min depth: 4
# Nodes: 17
# Answers: 8
#
# 13: [p7(X0, X0), p6(X0), p1(X0), p7(X0, a10)]
# Restart...
# Restart...
# min depth: 2
# Nodes: 100033
# Answers: 604
#
# 14: [p7(X0, X8)]
# min depth: 3
# Nodes: 100060
# Answers: 396
#
# 15: [p7(a75, a71)]
# min depth: 3
# Nodes: 23
# Answers: 8
#
# 16: [p1(a56)]
# Restart...
# min depth: 3
# Nodes: 55103
# Answers: 14
#
# 17: [p4(X3, a4, X3, a4, X9)]
# min depth: 2
# Nodes: 4
# Answers: 1
#
# 18: [p7(X9, X9)]
# Restart...
# Restart...
# min depth: 2
# Nodes: 100041
# Answers: 160
#
# 19: [p0(X6)]
# min depth: 2
# Nodes: 100062
# Answers: 667
#
# 20: [p9(X0, a7, a83), p4(a18, a0, X0, a23, a60)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 21: [p7(X6, X6)]
# min depth: 2
# Nodes: 100044
# Answers: 768
#
# 22: [p7(X9, X9)]
# Restart...
# min depth: 2
# Nodes: 100048
# Answers: 355
#
# 23: [p1(X0)]
# Nodes: 100066
# Answers: 14
#
# 24: [p4(a51, a38, a48, X0, a23), p4(a28, X0, a28, X0, a55), p7(X0, X0)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 25: [p9(X1, a75, X0), p9(X0, a7, a83), p4(a22, a26, X1, a0, a45)]
# min depth: 2
# Nodes: 13774
# Answers: 278
#
# 26: [p9(a29, a75, X0), p4(X0, a0, a0, a64, a63)]
# min depth: 2
# Nodes: 4
# Answers: 1
#
# 27: [p0(X1)]
# min depth: 1
# Nodes: 100106
# Answers: 489
#
# 28: [p1(X1)]
# min depth: 1
# Nodes: 97241
# Answers: 1000
#
# 29: [p3(X3, X0), p4(X1, X2, X0, X3, a13), p7(X1, X1), p4(a11, X3, a11, X3, a55)]
# min depth: 1
# Nodes: 25270
# Answers: 480
#
# 30: [p0(X0), p7(X0, X0), p7(X0, X0), p3(X0, a13)]
# min depth: 2
# Nodes: 82634
# Answers: 1000
#
# 31: [p1(X0)]
# min depth: 1
# Nodes: 100078
# Answers: 232
#
# 32: [p1(X0), p4(a13, X0, a13, X0, a55), p9(X0, X1, a2), p7(a12, X0), p9(a46, X1, a10)]
# min depth: 1
# Nodes: 56434
# Answers: 1000
#
# 33: [p0(X9)]
# min depth: 1
# Nodes: 100047
# Answers: 40
#
# 34: [p8(a25, X0), p4(X0, a25, X0, a25, X1), p4(X2, a9, X2, a9, X1), p2(X1), p4(a19, X2, a19, X2, X1)]
# min depth: 1
# Mismatched predicates: p4(X0, a25, X0, a25, X1) with p3(X0, a25)
# Nodes: 3
# Answers: 1
#
# 35: [p4(a10, X0, a94, a19, a30), p7(X0, X0)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 36: [p9(X8, X8, a43)]
# min depth: 5
# Nodes: 158
# Answers: 67
#
# 37: [p7(X2, X2)]
# min depth: 2
# Nodes: 100057
# Answers: 346
#
# 38: [p0(a59)]
# Restart...
# Restart...
# Nodes: 100078
# Answers: 1
#
# 39: [p9(X9, X2, a85)]
# min depth: 1
# Nodes: 22
# Answers: 13
#
# 40: [p7(X8, X8)]
# Restart...
# min depth: 3
# Nodes: 100062
# Answers: 482
#
# 41: [p7(X7, X7)]
# min depth: 2
# Nodes: 100061
# Answers: 934
#
# 42: [p7(X0, X0), p0(X0), p7(X0, X0)]
# min depth: 3
# Nodes: 100060
# Answers: 218
#
# 43: [p9(X8, a75, X2)]
# min depth: 2
# Nodes: 41312
# Answers: 40
#
# 44: [p7(X0, X0), p4(X0, a64, X0, a64, X1), p4(a1, a77, a1, a77, X1)]
# min depth: 2
# Nodes: 71341
# Answers: 799
#
# 45: [p7(X7, X7)]
# min depth: 2
# Nodes: 100057
# Answers: 40
#
# 46: [p7(X1, X0), p1(X0), p1(X1), p8(X0, a28)]
# min depth: 1
# Nodes: 90788
# Answers: 1000
#
# 47: [p4(a40, a91, a17, a17, X0), p7(a10, X0)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 48: [p4(X0, a5, a42, a17, a13), p7(X0, X0)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 49: [p9(a92, a45, X0), p1(X0)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 50: [p7(X4, X4)]
# Restart...
# min depth: 2
# Nodes: 100055
# Answers: 883
#
# 51: [p7(X5, X5)]
# Restart...
# min depth: 2
# Nodes: 100028
# Answers: 1000
#
# 52: [p8(X0, a28), p7(X0, X0), p0(X0)]
# min depth: 1
# Mismatched predicates: p7(X0, X0) with p3(a28, X0)
# Nodes: 3
# Answers: 1
#
# 53: [p7(X0, X0), p1(X0), p7(X0, X0)]
# min depth: 2
# Nodes: 100027
# Answers: 346
#
# 54: [p1(X0), p0(X0)]
# min depth: 1
# Nodes: 31978
# Answers: 1000
#
# 55: [p7(X0, X0), p0(X0), p7(X0, X0), p1(X0), p7(a0, X0)]
# min depth: 2
# Nodes: 62381
# Answers: 1000
#
# 56: [p0(X3)]
# min depth: 2
# Nodes: 100083
# Answers: 372
#
# 57: [p7(X0, X0), p0(X0)]
# Nodes: 100129
# Answers: 16
#
# 58: [p4(a79, a21, a18, a43, X0), p9(X0, a27, a0)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 59: [p4(X2, X4, X2, X4, a55)]
# min depth: 2
# Nodes: 19
# Answers: 16
#
# 60: [p7(X4, a85)]
# Restart...
# min depth: 2
# Nodes: 36407
# Answers: 36
#
# 61: [p7(X7, X7)]
# min depth: 2
# Nodes: 100065
# Answers: 476
#
# 62: [p1(X4)]
# min depth: 1
# Nodes: 71428
# Answers: 1000
#
# 63: [p8(X0, X1), p9(a92, X0, a10), p4(X1, X0, X1, X0, a55)]
# min depth: 1
# Mismatched predicates: p9(a92, X0, a10) with p3(X1, a49)
# Nodes: 18
# Answers: 16
#
# 64: [p4(a62, a29, a62, a29, X1)]
# min depth: 2
# Nodes: 4
# Answers: 1
#
# 65: [p7(X0, X0), p4(X0, X1, X0, X1, a55), p3(X1, a11), p0(X1)]
# min depth: 2
# Nodes: 46391
# Answers: 1000
#
# 66: [p4(X1, X0, a0, a3, X2), p9(X1, a98, a71), p4(a0, a89, a20, X2, a16)]
# min depth: 1
# Nodes: 4
# Answers: 1
#
# 67: [p4(a52, X0, a52, X0, a55)]
# min depth: 2
# Nodes: 4
# Answers: 1
#
# 68: [p0(a53)]
# Restart...
# min depth: 4
# Nodes: 41030
# Answers: 23
#
# 69: [p4(a13, X4, a13, X4, X9)]
# min depth: 2
# Nodes: 4
# Answers: 1
#
# 70: [p7(X6, X6)]
# min depth: 2
# Nodes: 100062
# Answers: 734
#
# 71: [p4(a91, a78, a0, X0, a1), p5(a0, X0)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 72: [p1(a10)]
# Restart...
# Restart...
# Answers: 0
#
# 73: [p8(a92, X0), p4(X0, a92, X0, a92, a55), p4(X0, a51, X1, a95, a10), p1(X1), p7(X0, X0)]
#  [-----] 0.0% to max nodes (135062 nps)Mismatched predicates: p4(X0, a92, X0, a92, a55) with p3(X0, a49)
# min depth: 1
# Nodes: 3
# Answers: 1
#
# 74: [p9(a20, a97, X0), p7(a97, X0)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 75: [p9(X0, a38, a85), p4(X0, a20, X0, a20, a55)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 76: [p7(X7, a12)]
# min depth: 2
# Nodes: 55886
# Answers: 90
#
# 77: [p1(X7)]
# min depth: 1
# Nodes: 60899
# Answers: 1000
#
# 78: [p7(X4, a41)]
# min depth: 4
# Nodes: 62758
# Answers: 18
#
# 79: [p7(X7, X7)]
# min depth: 2
# Nodes: 100062
# Answers: 521
#
# 80: [p7(X0, X0), p4(a0, X0, a0, X0, a55), p7(X0, X0), p7(a25, X0), p4(a0, X0, a0, X0, a55)]
# Restart...
# min depth: 3
# Nodes: 100065
# Answers: 96
#
# 81: [p4(a32, X1, a45, X0, a57), p9(X0, a29, a10), p8(a9, X1)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 82: [p1(X1)]
# Nodes: 100068
# Answers: 14
#
# 83: [p7(X2, X1)]
# min depth: 1
# Nodes: 100068
# Answers: 983
#
# 84: [p1(X0), p7(X0, X0), p3(X0, a46), p0(X0)]
# min depth: 1
# Nodes: 100074
# Answers: 165
#
# 85: [p7(a97, X1)]
# Restart...
# Restart...
# min depth: 2
# Nodes: 52401
# Answers: 2
#
# 86: [p1(X9)]
# min depth: 1
# Nodes: 100038
# Answers: 582
#
# 87: [p4(a11, X2, a11, X2, a55)]
# min depth: 2
# Nodes: 5
# Answers: 2
#
# 88: [p7(X0, X0), p3(X0, X1), p7(X1, X1), p4(a59, X0, a59, X0, a55)]
# Restart...
# min depth: 4
# Nodes: 26127
# Answers: 1000
#
# 89: [p0(a46)]
# Restart...
# Restart...
# Answers: 0
#
# 90: [p1(X7)]
# min depth: 1
# Nodes: 25075
# Answers: 1000
#
# 91: [p9(X0, X0, a12)]
# min depth: 3
# Nodes: 136
# Answers: 57
#
# 92: [p0(X0), p7(X0, X0), p7(X0, X1), p7(a75, X1)]
# min depth: 1
# Mismatched predicates: p7(X0, X0) with p3(a90, X0)
# Nodes: 100052
# Answers: 912
#
# 93: [p4(X8, X4, X8, X4, X3)]
# min depth: 2
# Nodes: 28647
# Answers: 32
#
# 94: [p8(X1, X0), p7(a51, X0), p3(X1, X2), p9(a76, a75, X1), p1(X2)]
# min depth: 1
# Mismatched predicates: p7(a51, X0) with p3(X0, a49)
# Nodes: 18
# Answers: 16
#
# 95: [p7(X0, X3)]
# min depth: 1
# Nodes: 65777
# Answers: 1000
#
# 96: [p9(a76, X1, X3)]
# min depth: 2
# Nodes: 9
# Answers: 4
#
# 97: [p4(a86, X1, a11, X0, a97), p9(a75, a75, X0), p1(X1)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 98: [p4(a40, X0, X2, X2, X1), p4(X0, a46, a41, a80, a12), p7(a23, X1), p7(a10, X1), p4(a40, X0, X2, X2, X1)]
# min depth: 1
# Nodes: 4
# Answers: 1
#
# 99: [p7(a75, X1)]
# Restart...
# Restart...
# Answers: 0
#
# 100: [p7(X0, X0)]
# min depth: 2
# Nodes: 93844
# Answers: 1000
#
# Before removing duplicates: 2403150 examples
# After removing duplicates: 25833 examples
# Replicating pos examples 9 times
# pos len=23538, neg len=23538

# %%
# !{sys.executable} ../nnreasoner.py --embed_type unification
# Out:
# States from vocab: vocab
# Num predicates: 10
# Max arity: 5
# Num constants: 100
# Num variables: 10
#
# Training unification
# Embed size: 50
# Reading examples from mr_train_examples.csv
# Parsing examples...
# Generating embeddings...
# Embedding input size: 560
#  [███████████████] 47075/47075 Prepping examples
# Loaded data...
# Using cuda device
# 0	0.45046 (-)
# 50	0.28054 (-0.0026)
# 100	0.26603 (-0.0014)
# 150	0.25791 (-0.0010)
# 200	0.25110 (-0.0008)
# 250	0.24557 (-0.0006)
# 300	0.23958 (-0.0005)
# 350	0.23480 (-0.0005)
# 400	0.23040 (-0.0004)
# 450	0.22757 (-0.0004)
# 500	0.22429 (-0.0003)
# 550	0.22189 (-0.0003)
# 600	0.21934 (-0.0003)
# 650	0.21789 (-0.0003)
# 700	0.21533 (-0.0002)
# 750	0.21366 (-0.0002)
# 800	0.21172 (-0.0002)
# 850	0.21005 (-0.0002)
# 900	0.20722 (-0.0002)
# 950	0.20519 (-0.0002)
# 1000	0.20415 (-0.0002)
# 1050	0.20148 (-0.0002)
# 1100	0.20052 (-0.0001)
# 1150	0.19740 (-0.0001)
# 1200	0.19457 (-0.0001)
# 1249	0.19424 (-0.0001)
# Saved training loss figure.

# %%
img = plt.imread('guided_loss-unification10-100-5-50.png')
plt. imshow(img)

# %%
# !{sys.executable}  ../evaluate.py --kb randomKB.txt -s
# !{sys.executable} ../evaluate.py --kb randomKB.txt -u
# Out:
# using cuda device
# STANDARD
#
# Query 1: [p1(X2)]
# 2 :: 1 - 00:00:00 (5885 nps)
#
# Query 2: [p7(a7, X5)]
# Query failed!!!
# 1000000 :: 0 - 00:00:45 (21919 nps)
#
# Query 3: [p2(X0)]
# 2 :: 1 - 00:00:00 (6759 nps)
#
# Query 4: [p9(X2, a75, X5)]
# Query failed!!!
# 1000000 :: 0 - 00:00:41 (23852 nps)
#
# Query 5: [p7(X9, X9)]
# 14 :: 3 - 00:00:00 (5480 nps)
#
# Query 6: [p4(a22, X0, a1, X2, a45), p5(X0, X1), p8(X1, a94), p7(X2, X2)]
# 12 :: 8 - 00:00:00 (4281 nps)
#
# Query 7: [p7(X0, X0), p7(X0, X0), p1(X0)]
# 18 :: 7 - 00:00:00 (13201 nps)
#
# Query 8: [p7(X5, X1)]
# 2 :: 1 - 00:00:00 (5028 nps)
#
# Query 9: [p1(X0), p4(a86, X1, a11, X2, X0), p1(X1), p7(X1, X1), p4(X2, a26, a1, a0, a45)]
# Query failed!!!
# 1000000 :: 0 - 00:01:03 (15668 nps)
#
# Query 10: [p7(X8, X8)]
# 14 :: 3 - 00:00:00 (5495 nps)
#
# Query 11: [p7(a21, a21)]
# Query failed!!!
# 1000000 :: 0 - 00:00:40 (24936 nps)
#
# Query 12: [p7(X9, a10)]
# 2 :: 1 - 00:00:00 (5542 nps)
#
# Query 13: [p9(X2, X2, a2)]
# 4 :: 3 - 00:00:00 (5015 nps)
#
# Query 14: [p7(X6, X3)]
# 2 :: 1 - 00:00:00 (5061 nps)
#
# Query 15: [p1(X1)]
# 2 :: 1 - 00:00:00 (8122 nps)
#
# Query 16: [p7(X0, X0), p3(X0, X1), p4(a0, X2, a20, X1, a16), p7(X1, X1), p7(X2, X2)]
# Query failed!!!
# 1000000 :: 0 - 00:01:02 (16068 nps)
#
# Query 17: [p7(X0, X0)]
# 14 :: 3 - 00:00:00 (5330 nps)
#
# Query 18: [p7(a23, X0), p7(X1, X0), p1(X1), p1(X0), p9(a17, a76, X1)]
# 26530 :: 12 - 00:00:01 (21723 nps)
#
# Query 19: [p9(a12, a75, X6)]
# 3 :: 2 - 00:00:00 (4404 nps)
#
# Query 20: [p3(X0, X1), p1(X0), p9(a45, X2, X1), p7(X0, X0), p9(a46, X2, a10)]
# Query failed!!!
# 1000000 :: 0 - 00:00:55 (17902 nps)
#
# Query 21: [p8(X0, X2), p7(X1, X0), p9(a43, X1, X0), p4(a47, a40, X2, a21, X2)]
# Query failed!!!
# 1000000 :: 0 - 00:00:57 (17385 nps)
#
# Query 22: [p0(X0), p1(X0), p9(X0, a46, a10)]
# Query failed!!!
# 1000000 :: 0 - 00:00:42 (23773 nps)
#
# Query 23: [p4(X1, X0, X1, X0, a55), p4(a51, a38, a48, X0, a23), p8(X0, X1), p1(X1)]
# 9 :: 5 - 00:00:00 (3624 nps)
#
# Query 24: [p4(a51, a38, a48, a54, X0), p7(X0, X0), p0(X0), p6(X0)]
# Query failed!!!
# 1000000 :: 0 - 00:00:52 (19085 nps)
#
# Query 25: [p9(a92, X1, X0), p7(a40, X0), p7(X1, X0), p7(X2, X0), p9(X2, X2, a2)]
# Query failed!!!
# 1000000 :: 0 - 00:00:39 (25065 nps)
#
# Query 26: [p7(X3, X3)]
# 14 :: 3 - 00:00:00 (5382 nps)
#
# Query 27: [p4(a1, a15, a60, X1, X0), p4(a1, X0, a80, X3, X0), p4(X1, a49, X3, a22, X2), p5(a50, X2), p4(a13, a55, a32, X3, a71)]
# 6 :: 5 - 00:00:00 (3365 nps)
#
# Query 28: [p7(X9, X9)]
# 14 :: 3 - 00:00:00 (22867 nps)
#
# Query 29: [p7(a38, X0), p9(a14, a38, X0), p9(a38, a75, X0)]
# Query failed!!!
# 1000000 :: 0 - 00:00:54 (18404 nps)
#
# Query 30: [p9(a75, a75, a2)]
# 4 :: 3 - 00:00:00 (4919 nps)
#
# Query 31: [p9(X1, X1, a57)]
# 4 :: 3 - 00:00:00 (5094 nps)
#
# Query 32: [p7(a75, X8)]
# Query failed!!!
# 1000000 :: 0 - 00:00:46 (21626 nps)
#
# Query 33: [p3(X0, a90), p8(X1, X0), p5(X1, a98), p4(a10, a89, a94, X0, a30)]
# 5 :: 4 - 00:00:00 (4593 nps)
#
# Query 34: [p3(X0, a12), p1(X0)]
# Query failed!!!
# 1000000 :: 0 - 00:00:42 (23799 nps)
#
# Query 35: [p3(a71, X5)]
# 3 :: 2 - 00:00:00 (4784 nps)
#
# Query 36: [p0(X1)]
# 2 :: 1 - 00:00:00 (6445 nps)
#
# Query 37: [p7(X5, X1)]
# 2 :: 1 - 00:00:00 (4759 nps)
#
# Query 38: [p1(a10)]
# 7216 :: 12 - 00:00:00 (19914 nps)
#
# Query 39: [p9(X0, X0, a83), p9(X0, X0, X1), p7(X0, X1), p4(X1, a49, a82, a14, a74), p1(X1)]
# 175338 :: 11 - 00:00:08 (20390 nps)
#
# Query 40: [p7(X0, a10)]
# 2 :: 1 - 00:00:00 (6070 nps)
#
# Query 41: [p9(X8, X8, X6)]
# Query failed!!!
# 1000000 :: 0 - 00:00:42 (23409 nps)
#
# Query 42: [p7(X9, X9)]
# 14 :: 3 - 00:00:00 (5211 nps)
#
# Query 43: [p0(a53)]
# 6 :: 3 - 00:00:00 (4278 nps)
#
# Query 44: [p7(a29, a29)]
# Query failed!!!
# 1000000 :: 0 - 00:00:40 (24815 nps)
#
# Query 45: [p4(a1, X0, a1, X0, X1), p3(a4, X0), p9(a69, a75, X1)]
# 7 :: 5 - 00:00:00 (1807 nps)
#
# Query 46: [p7(X7, X7)]
# 14 :: 3 - 00:00:00 (3342 nps)
#
# Query 47: [p4(a93, X1, a50, X0, a4), p1(X0), p0(X0), p3(a8, X1)]
# Query failed!!!
# 1000000 :: 0 - 00:00:50 (19872 nps)
#
# Query 48: [p0(X7)]
# 2 :: 1 - 00:00:00 (5291 nps)
#
# Query 49: [p1(X3)]
# 2 :: 1 - 00:00:00 (7917 nps)
#
# Query 50: [p4(a0, X0, a0, X0, a55), p4(a0, X0, a0, X0, a55), p7(a25, X0)]
# 6 :: 5 - 00:00:00 (4236 nps)
#
# Query 51: [p7(X2, a16)]
# Query failed!!!
# 1000000 :: 0 - 00:00:46 (21364 nps)
#
# Query 52: [p9(X5, X5, a12)]
# 4 :: 3 - 00:00:00 (3761 nps)
#
# Query 53: [p7(X3, X3)]
# 14 :: 3 - 00:00:00 (5185 nps)
#
# Query 54: [p4(a52, X0, a52, X0, a55), p7(X0, X0)]
# Query failed!!!
# 1000000 :: 0 - 00:00:42 (23323 nps)
#
# Query 55: [p1(X3)]
# 2 :: 1 - 00:00:00 (7619 nps)
#
# Query 56: [p7(X6, X6)]
# 14 :: 3 - 00:00:00 (5483 nps)
#
# Query 57: [p3(X0, a14), p1(X0)]
# Query failed!!!
# 1000000 :: 0 - 00:00:42 (23296 nps)
#
# Query 58: [p1(X5)]
# 2 :: 1 - 00:00:00 (7546 nps)
#
# Query 59: [p3(X0, X1), p7(X0, X0), p4(X1, a17, X1, a17, X2), p4(a1, a12, a1, a12, X2)]
# Query failed!!!
# 1000000 :: 0 - 00:00:59 (16736 nps)
#
# Query 60: [p4(a69, a0, X0, a68, a68), p9(a55, X0, X1), p7(X0, X1)]
# 5 :: 4 - 00:00:00 (4206 nps)
#
# Query 61: [p7(X7, a71)]
# Query failed!!!
# 1000000 :: 0 - 00:00:44 (22498 nps)
#
# Query 62: [p3(X0, a11), p0(X0), p7(X0, X0), p4(a59, X0, a59, X0, a55)]
# Query failed!!!
# 1000000 :: 0 - 00:00:46 (21484 nps)
#
# Query 63: [p4(X0, a0, a0, X2, X1), p7(X0, X0), p4(a28, a16, a0, X1, a27), p7(X0, a9), p3(X2, a11)]
# 26531 :: 14 - 00:00:01 (19439 nps)
#
# Query 64: [p7(X9, X9)]
# 14 :: 3 - 00:00:00 (5850 nps)
#
# Query 65: [p1(X0), p7(X0, X0), p7(X0, X0), p3(X0, a28)]
# Query failed!!!
# 1000000 :: 0 - 00:00:54 (18367 nps)
#
# Query 66: [p9(X2, X2, X3)]
# Query failed!!!
# 1000000 :: 0 - 00:00:43 (23232 nps)
#
# Query 67: [p7(X6, X6)]
# 14 :: 3 - 00:00:00 (5052 nps)
#
# Query 68: [p0(X7)]
# 2 :: 1 - 00:00:00 (5737 nps)
#
# Query 69: [p4(a10, X0, X0, a64, a63), p3(a6, X0)]
# 3 :: 2 - 00:00:00 (4536 nps)
#
# Query 70: [p4(X0, X1, a10, a21, a10), p7(X1, X2), p9(a45, a75, X2)]
# 5 :: 4 - 00:00:00 (3994 nps)
#
# Query 71: [p0(X3)]
# 2 :: 1 - 00:00:00 (6710 nps)
#
# Query 72: [p7(X0, X1), p0(X0), p9(X1, X2, a0), p3(a16, X0), p4(X2, a16, X2, a16, a55)]
# Query failed!!!
# 1000000 :: 0 - 00:00:58 (17131 nps)
#
# Query 73: [p1(X9)]
# 2 :: 1 - 00:00:00 (6637 nps)
#
# Query 74: [p4(X1, a0, a86, a0, X0), p0(X1), p9(a17, X1, a10)]
# 6 :: 5 - 00:00:00 (3871 nps)
#
# Query 75: [p1(X5)]
# 2 :: 1 - 00:00:00 (7918 nps)
#
# Query 76: [p7(X7, a28)]
# 4 :: 3 - 00:00:00 (6127 nps)
#
# Query 77: [p9(X2, X7, X4)]
# 2 :: 1 - 00:00:00 (4148 nps)
#
# Query 78: [p4(a15, a49, a82, X0, a74), p4(X0, X2, X0, X2, X1), p4(a59, a64, a59, a64, X1), p7(X2, a15)]
# 8 :: 7 - 00:00:00 (3898 nps)
#
# Query 79: [p7(X0, a22), p9(X0, X0, X1), p9(a7, X0, X1)]
# Query failed!!!
# 1000000 :: 0 - 00:00:52 (19004 nps)
#
# Query 80: [p9(a98, X9, X8)]
# 3 :: 2 - 00:00:00 (4252 nps)
#
# Query 81: [p7(X0, X0), p3(X0, X1), p8(X2, X1), p4(X1, X2, X1, X2, a55)]
# Query failed!!!
# 1000000 :: 0 - 00:00:55 (17940 nps)
#
# Query 82: [p4(X2, a0, X2, a0, X0), p9(a69, X1, X0), p9(a27, X1, a0), p4(X2, a0, X2, a0, X0), p2(X2)]
# 21 :: 11 - 00:00:00 (4928 nps)
#
# Query 83: [p4(a91, X0, a0, a3, a1)]
# 2 :: 1 - 00:00:00 (5544 nps)
#
# Query 84: [p9(X0, X0, X3)]
# Query failed!!!
# 1000000 :: 0 - 00:00:41 (24206 nps)
#
# Query 85: [p7(X8, X8)]
# 14 :: 3 - 00:00:00 (5095 nps)
#
# Query 86: [p0(X7)]
# 2 :: 1 - 00:00:00 (5438 nps)
#
# Query 87: [p9(X5, a75, X0)]
# Query failed!!!
# 1000000 :: 0 - 00:00:42 (23671 nps)
#
# Query 88: [p0(X3)]
# 2 :: 1 - 00:00:00 (6154 nps)
#
# Query 89: [p4(X1, X0, X2, X0, a31), p7(a13, X0), p5(X1, a1), p4(X2, a49, a11, a22, a97), p4(a1, a15, a60, X2, X0)]
# 7 :: 6 - 00:00:00 (4175 nps)
#
# Query 90: [p4(X0, a91, a17, a17, a35), p4(a47, X0, a10, a21, a10)]
# 3 :: 2 - 00:00:00 (4698 nps)
#
# Query 91: [p7(X9, X9)]
# 14 :: 3 - 00:00:00 (5739 nps)
#
# Query 92: [p2(X0), p7(X0, X0), p3(X0, X1), p8(X1, a19), p7(X0, X0)]
# Query failed!!!
# 1000000 :: 0 - 00:00:49 (20098 nps)
#
# Query 93: [p1(X2)]
# 2 :: 1 - 00:00:00 (7041 nps)
#
# Query 94: [p3(X0, X1), p2(X0)]
# Query failed!!!
# 1000000 :: 0 - 00:00:43 (22919 nps)
#
# Query 95: [p7(a75, X0), p7(a7, X0), p9(X1, a7, X0), p9(X2, a1, X1), p4(a22, a26, a1, X2, a45)]
# Query failed!!!
# 1000000 :: 0 - 00:01:05 (15188 nps)
#
# Query 96: [p9(X9, X9, a12)]
# 4 :: 3 - 00:00:00 (4809 nps)
#
# Query 97: [p7(X0, X0), p4(X2, X0, X2, X0, X1), p4(a94, a25, a94, a25, X1), p4(X2, a17, X2, a17, X1)]
# Query failed!!!
# 1000000 :: 0 - 00:01:00 (16486 nps)
#
# Query 98: [p9(X3, X0, X2), p9(X0, X1, X2), p9(a77, X1, a57), p6(X2), p9(X3, a61, a12)]
# Query failed!!!
# 1000000 :: 0 - 00:00:38 (25894 nps)
#
# Query 99: [p1(X5)]
# 2 :: 1 - 00:00:00 (7618 nps)
#
# Query 100: [p8(X0, a52), p0(X0), p1(X0)]
# 122591 :: 14 - 00:00:03 (34128 nps)
#
# std: 343585.94 nodes/query
# 34 queries failed
# Time to run all queries: 1682.2125141290003
# using cuda device
# UNITY: ming
# 	Embedding Model: rKB_model.pth
# 	Scoring Model: uni_mr_model.pt
#
# 	Control: mingoal
# 	Rule Eval: Max Rule
# Learned Embedding: Network using cuda
# Query 1: [p1(X2)]
# 2 :: 1 - 00:00:00 (21 nps)
#
# Query 2: [p7(a7, X5)]
# Query failed!!!
# 1000000 :: 0 - 00:02:29 (6696 nps)
#
# Query 3: [p2(X0)]
# 2 :: 1 - 00:00:00 (143 nps)
#
# Query 4: [p9(X2, a75, X5)]
# 3 :: 2 - 00:00:00 (155 nps)
#
# Query 5: [p7(X9, X9)]
# 3 :: 2 - 00:00:00 (144 nps)
#
# Query 6: [p4(a22, X0, a1, X2, a45), p5(X0, X1), p8(X1, a94), p7(X2, X2)]
# Query failed!!!
# 1000000 :: 0 - 00:03:17 (5073 nps)
#
# Query 7: [p7(X0, X0), p7(X0, X0), p1(X0)]
# Query failed!!!
# 1000000 :: 0 - 00:02:17 (7292 nps)
#
# Query 8: [p7(X5, X1)]
# 2 :: 1 - 00:00:00 (114 nps)
#
# Query 9: [p1(X0), p4(a86, X1, a11, X2, X0), p1(X1), p7(X1, X1), p4(X2, a26, a1, a0, a45)]
# 458403 :: 15 - 00:00:41 (11067 nps)
#
# Query 10: [p7(X8, X8)]
# 3 :: 2 - 00:00:00 (146 nps)
#
# Query 11: [p7(a21, a21)]
# 5 :: 2 - 00:00:00 (441 nps)
#
# Query 12: [p7(X9, a10)]
# 2 :: 1 - 00:00:00 (435 nps)
#
# Query 13: [p9(X2, X2, a2)]
# 4 :: 3 - 00:00:00 (881 nps)
#
# Query 14: [p7(X6, X3)]
# 2 :: 1 - 00:00:00 (117 nps)
#
# Query 15: [p1(X1)]
# 2 :: 1 - 00:00:00 (29476 nps)
#
# Query 16: [p7(X0, X0), p3(X0, X1), p4(a0, X2, a20, X1, a16), p7(X1, X1), p7(X2, X2)]
# Query failed!!!
# 1000000 :: 0 - 00:02:08 (7757 nps)
#
# Query 17: [p7(X0, X0)]
# 3 :: 2 - 00:00:00 (169 nps)
#
# Query 18: [p7(a23, X0), p7(X1, X0), p1(X1), p1(X0), p9(a17, a76, X1)]
# 835295 :: 7 - 00:02:02 (6820 nps)
#
# Query 19: [p9(a12, a75, X6)]
# 3 :: 2 - 00:00:00 (826 nps)
#
# Query 20: [p3(X0, X1), p1(X0), p9(a45, X2, X1), p7(X0, X0), p9(a46, X2, a10)]
# Query failed!!!
# 1000000 :: 0 - 00:01:33 (10744 nps)
#
# Query 21: [p8(X0, X2), p7(X1, X0), p9(a43, X1, X0), p4(a47, a40, X2, a21, X2)]
# 6 :: 5 - 00:00:00 (94 nps)
#
# Query 22: [p0(X0), p1(X0), p9(X0, a46, a10)]
# 50 :: 15 - 00:00:00 (391 nps)
#
# Query 23: [p4(X1, X0, X1, X0, a55), p4(a51, a38, a48, X0, a23), p8(X0, X1), p1(X1)]
# 11 :: 4 - 00:00:00 (174 nps)
#
# Query 24: [p4(a51, a38, a48, a54, X0), p7(X0, X0), p0(X0), p6(X0)]
# 5 :: 4 - 00:00:00 (102 nps)
#
# Query 25: [p9(a92, X1, X0), p7(a40, X0), p7(X1, X0), p7(X2, X0), p9(X2, X2, a2)]
# 13489 :: 10 - 00:00:03 (3464 nps)
#
# Query 26: [p7(X3, X3)]
# 3 :: 2 - 00:00:00 (144 nps)
#
# Query 27: [p4(a1, a15, a60, X1, X0), p4(a1, X0, a80, X3, X0), p4(X1, a49, X3, a22, X2), p5(a50, X2), p4(a13, a55, a32, X3, a71)]
# 6 :: 5 - 00:00:00 (253 nps)
#
# Query 28: [p7(X9, X9)]
# 3 :: 2 - 00:00:00 (139 nps)
#
# Query 29: [p7(a38, X0), p9(a14, a38, X0), p9(a38, a75, X0)]
# 6 :: 5 - 00:00:00 (299 nps)
#
# Query 30: [p9(a75, a75, a2)]
# 4 :: 3 - 00:00:00 (1238 nps)
#
# Query 31: [p9(X1, X1, a57)]
# 4 :: 3 - 00:00:00 (901 nps)
#
# Query 32: [p7(a75, X8)]
# 3202 :: 15 - 00:00:00 (9403 nps)
#
# Query 33: [p3(X0, a90), p8(X1, X0), p5(X1, a98), p4(a10, a89, a94, X0, a30)]
# 5 :: 4 - 00:00:00 (174 nps)
#
# Query 34: [p3(X0, a12), p1(X0)]
# 36 :: 15 - 00:00:00 (368 nps)
#
# Query 35: [p3(a71, X5)]
# 3 :: 2 - 00:00:00 (167 nps)
#
# Query 36: [p0(X1)]
# 2 :: 1 - 00:00:00 (120 nps)
#
# Query 37: [p7(X5, X1)]
# 2 :: 1 - 00:00:00 (120 nps)
#
# Query 38: [p1(a10)]
# Query failed!!!
# 1000000 :: 0 - 00:02:26 (6834 nps)
#
# Query 39: [p9(X0, X0, a83), p9(X0, X0, X1), p7(X0, X1), p4(X1, a49, a82, a14, a74), p1(X1)]
# 1611 :: 11 - 00:00:01 (1025 nps)
#
# Query 40: [p7(X0, a10)]
# 2 :: 1 - 00:00:00 (414 nps)
#
# Query 41: [p9(X8, X8, X6)]
# 4 :: 3 - 00:00:00 (173 nps)
#
# Query 42: [p7(X9, X9)]
# 3 :: 2 - 00:00:00 (134 nps)
#
# Query 43: [p0(a53)]
# 33 :: 15 - 00:00:00 (316 nps)
#
# Query 44: [p7(a29, a29)]
# 3 :: 2 - 00:00:00 (310 nps)
#
# Query 45: [p4(a1, X0, a1, X0, X1), p3(a4, X0), p9(a69, a75, X1)]
# 6 :: 5 - 00:00:00 (413 nps)
#
# Query 46: [p7(X7, X7)]
# 3 :: 2 - 00:00:00 (134 nps)
#
# Query 47: [p4(a93, X1, a50, X0, a4), p1(X0), p0(X0), p3(a8, X1)]
# 32 :: 15 - 00:00:00 (173 nps)
#
# Query 48: [p0(X7)]
# 2 :: 1 - 00:00:00 (112 nps)
#
# Query 49: [p1(X3)]
# 2 :: 1 - 00:00:00 (155 nps)
#
# Query 50: [p4(a0, X0, a0, X0, a55), p4(a0, X0, a0, X0, a55), p7(a25, X0)]
# 4 :: 3 - 00:00:00 (252 nps)
#
# Query 51: [p7(X2, a16)]
# 89473 :: 4 - 00:00:08 (10196 nps)
#
# Query 52: [p9(X5, X5, a12)]
# 4 :: 3 - 00:00:00 (898 nps)
#
# Query 53: [p7(X3, X3)]
# 3 :: 2 - 00:00:00 (144 nps)
#
# Query 54: [p4(a52, X0, a52, X0, a55), p7(X0, X0)]
# 5057 :: 8 - 00:00:00 (7317 nps)
#
# Query 55: [p1(X3)]
# 2 :: 1 - 00:00:00 (23675 nps)
#
# Query 56: [p7(X6, X6)]
# 3 :: 2 - 00:00:00 (137 nps)
#
# Query 57: [p3(X0, a14), p1(X0)]
# 22 :: 15 - 00:00:00 (367 nps)
#
# Query 58: [p1(X5)]
# 2 :: 1 - 00:00:00 (164 nps)
#
# Query 59: [p3(X0, X1), p7(X0, X0), p4(X1, a17, X1, a17, X2), p4(a1, a12, a1, a12, X2)]
# 2232 :: 15 - 00:00:00 (5448 nps)
#
# Query 60: [p4(a69, a0, X0, a68, a68), p9(a55, X0, X1), p7(X0, X1)]
# Query failed!!!
# 1000000 :: 0 - 00:02:35 (6411 nps)
#
# Query 61: [p7(X7, a71)]
# 171 :: 15 - 00:00:00 (794 nps)
#
# Query 62: [p3(X0, a11), p0(X0), p7(X0, X0), p4(a59, X0, a59, X0, a55)]
# 62 :: 15 - 00:00:00 (318 nps)
#
# Query 63: [p4(X0, a0, a0, X2, X1), p7(X0, X0), p4(a28, a16, a0, X1, a27), p7(X0, a9), p3(X2, a11)]
# Query failed!!!
# 1000000 :: 0 - 00:03:14 (5137 nps)
#
# Query 64: [p7(X9, X9)]
# 3 :: 2 - 00:00:00 (139 nps)
#
# Query 65: [p1(X0), p7(X0, X0), p7(X0, X0), p3(X0, a28)]
# 6 :: 5 - 00:00:00 (15 nps)
#
# Query 66: [p9(X2, X2, X3)]
# 4 :: 3 - 00:00:00 (179 nps)
#
# Query 67: [p7(X6, X6)]
# 3 :: 2 - 00:00:00 (144 nps)
#
# Query 68: [p0(X7)]
# 2 :: 1 - 00:00:00 (117 nps)
#
# Query 69: [p4(a10, X0, X0, a64, a63), p3(a6, X0)]
# 3 :: 2 - 00:00:00 (834 nps)
#
# Query 70: [p4(X0, X1, a10, a21, a10), p7(X1, X2), p9(a45, a75, X2)]
# 5 :: 4 - 00:00:00 (103 nps)
#
# Query 71: [p0(X3)]
# 2 :: 1 - 00:00:00 (119 nps)
#
# Query 72: [p7(X0, X1), p0(X0), p9(X1, X2, a0), p3(a16, X0), p4(X2, a16, X2, a16, a55)]
# 11 :: 6 - 00:00:00 (134 nps)
#
# Query 73: [p1(X9)]
# 2 :: 1 - 00:00:00 (166 nps)
#
# Query 74: [p4(X1, a0, a86, a0, X0), p0(X1), p9(a17, X1, a10)]
# 33 :: 15 - 00:00:00 (356 nps)
#
# Query 75: [p1(X5)]
# 2 :: 1 - 00:00:00 (162 nps)
#
# Query 76: [p7(X7, a28)]
# Query failed!!!
# 1000000 :: 0 - 00:02:45 (6031 nps)
#
# Query 77: [p9(X2, X7, X4)]
# 2 :: 1 - 00:00:00 (114 nps)
#
# Query 78: [p4(a15, a49, a82, X0, a74), p4(X0, X2, X0, X2, X1), p4(a59, a64, a59, a64, X1), p7(X2, a15)]
# 883697 :: 7 - 00:02:08 (6898 nps)
#
# Query 79: [p7(X0, a22), p9(X0, X0, X1), p9(a7, X0, X1)]
# 9 :: 8 - 00:00:00 (122 nps)
#
# Query 80: [p9(a98, X9, X8)]
# 3 :: 2 - 00:00:00 (776 nps)
#
# Query 81: [p7(X0, X0), p3(X0, X1), p8(X2, X1), p4(X1, X2, X1, X2, a55)]
# 1529 :: 15 - 00:00:00 (1675 nps)
#
# Query 82: [p4(X2, a0, X2, a0, X0), p9(a69, X1, X0), p9(a27, X1, a0), p4(X2, a0, X2, a0, X0), p2(X2)]
# 84776 :: 8 - 00:00:13 (6328 nps)
#
# Query 83: [p4(a91, X0, a0, a3, a1)]
# 2 :: 1 - 00:00:00 (1466 nps)
#
# Query 84: [p9(X0, X0, X3)]
# 4 :: 3 - 00:00:00 (176 nps)
#
# Query 85: [p7(X8, X8)]
# 3 :: 2 - 00:00:00 (141 nps)
#
# Query 86: [p0(X7)]
# 2 :: 1 - 00:00:00 (117 nps)
#
# Query 87: [p9(X5, a75, X0)]
# 3 :: 2 - 00:00:00 (155 nps)
#
# Query 88: [p0(X3)]
# 2 :: 1 - 00:00:00 (118 nps)
#
# Query 89: [p4(X1, X0, X2, X0, a31), p7(a13, X0), p5(X1, a1), p4(X2, a49, a11, a22, a97), p4(a1, a15, a60, X2, X0)]
# Query failed!!!
# 1000000 :: 0 - 00:02:54 (5720 nps)
#
# Query 90: [p4(X0, a91, a17, a17, a35), p4(a47, X0, a10, a21, a10)]
# 3 :: 2 - 00:00:00 (790 nps)
#
# Query 91: [p7(X9, X9)]
# 3 :: 2 - 00:00:00 (140 nps)
#
# Query 92: [p2(X0), p7(X0, X0), p3(X0, X1), p8(X1, a19), p7(X0, X0)]
# Query failed!!!
# 1000000 :: 0 - 00:02:14 (7460 nps)
#
# Query 93: [p1(X2)]
# 2 :: 1 - 00:00:00 (148 nps)
#
# Query 94: [p3(X0, X1), p2(X0)]
# Query failed!!!
# 1000000 :: 0 - 00:02:24 (6943 nps)
#
# Query 95: [p7(a75, X0), p7(a7, X0), p9(X1, a7, X0), p9(X2, a1, X1), p4(a22, a26, a1, X2, a45)]
# 74433 :: 8 - 00:00:14 (5311 nps)
#
# Query 96: [p9(X9, X9, a12)]
# 4 :: 3 - 00:00:00 (845 nps)
#
# Query 97: [p7(X0, X0), p4(X2, X0, X2, X0, X1), p4(a94, a25, a94, a25, X1), p4(X2, a17, X2, a17, X1)]
# 13 :: 8 - 00:00:00 (74 nps)
#
# Query 98: [p9(X3, X0, X2), p9(X0, X1, X2), p9(a77, X1, a57), p6(X2), p9(X3, a61, a12)]
# 8 :: 7 - 00:00:00 (49 nps)
#
# Query 99: [p1(X5)]
# 2 :: 1 - 00:00:00 (144 nps)
#
# Query 100: [p8(X0, a52), p0(X0), p1(X0)]
# Query failed!!!
# 1000000 :: 0 - 00:02:43 (6118 nps)
#
# ming: 154538.83 nodes/query
# 13 queries failed
# Time to run all queries: 2323.682015318001

# %%
# !ls *.csv
# Out:
# ming-10-100-5-50.csv  mr_train_examples.csv  std-10-100-5-50.csv  triplets.csv

# %%
# !head std-10-100-5-50.csv 
# !head ming-10-100-5-50.csv
# Out:
# query,std reasoner,std nodes explored,std min depth,success,time
# 1,std,2,1,True,0.0003397999999998902
# 2,std,1000000,0,False,45.622275941000005
# 3,std,2,1,True,0.0002958640000016999
# 4,std,1000000,0,False,41.92503278499999
# 5,std,14,3,True,0.0025545929999992723
# 6,std,12,8,True,0.002802617000000396
# 7,std,18,7,True,0.0013634739999872636
# 8,std,2,1,True,0.00039776299999516596
# 9,std,1000000,0,False,63.821950589
# query,ming reasoner,ming nodes explored,ming min depth,success,time
# 1,ming,2,1,True,0.09405308499999876
# 2,ming,1000000,0,False,149.336012305
# 3,ming,2,1,True,0.013919248000007656
# 4,ming,3,2,True,0.01932913900000699
# 5,ming,3,2,True,0.02081446900001538
# 6,ming,1000000,0,False,197.10546353100003
# 7,ming,1000000,0,False,137.13632440199996
# 8,ming,2,1,True,0.017427338999993935
# 9,ming,458403,15,True,41.41905820599999
