# %%
import matplotlib.pyplot as plt
import sys

# %%
# !{sys.executable} ../kbencoder.py --generate_kb --num_rules 300 --new_vocab --save_vocab
# Out:
# Classes: 1000000000.0
# Max arity: 4
# KB generated (300)

# %%
# !{sys.executable} ../kbencoder.py --kb_path randomKB.txt --train_unification_model
# Out:
# Using cuda device
# Uni model embed size: 50
#  [████████████████████] 3500/3500 Anchors generated
#  [████████████████████] 70000/70000 Triplets generated
#  [█████---------------] 18490/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [███████████---------] 41964/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [███████████████████-] 66862/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Early stopping triggered-------------] 29.1% Epoch | [Epoch 146/500, Training Loss: 0.1378, Validation Loss: 0.5249]
# Saved model.
# Saved plot.
# unification model generated

# %%
import glob
glob.glob('training_loss*.png')
# Out:
# ['training_loss-10-100-4-50.png']

# %%
img = plt.imread('training_loss-10-100-4-50.png')
plt. imshow(img)

# %%
# !{sys.executable} ../kbencoder.py --kb_path randomKB.txt -g
# Out:
# Generating facts list...
# Forward chaining depth: 1
# New facts: 105
# Forward chaining depth: 2
# New facts: 39
# Forward chaining depth: 3
# New facts: 6
# Forward chaining depth: 4
# New facts: 3
# Forward chaining depth: 5
#
# Facts list generated
# 153 total facts. Max depth = 4
#
# Number of queries: 200
# 100 training queries generated
# 100 testing queries generated

# %%
# !{sys.executable} ../kbencoder.py --kb_path randomKB.txt -p
# Out:
# running training queries...
# Negative facts will be generated
# 1: [p1(X0, a98, a80), p2(a7, X1, X0), p9(X1)]
# Nodes: 100141
# Answers: 1
#
# 2: [p9(X0)]
# min depth: 1
# Nodes: 100094
# Answers: 147
#
# 3: [p1(a17, a28, X0), p8(a19, a0, a0, X0), p0(X0, a15), p8(a8, a24, X1, X0), p1(a3, X1, a80)]
# Nodes: 100106
# Answers: 1
#
# 4: [p8(X0, a15, a76, a70), p4(X0, a1), p4(a24, X0)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 5: [p1(a28, X9, X9)]
# Restart...
# Restart...
# Answers: 0
#
# 6: [p4(a1, X1)]
# min depth: 1
# Nodes: 23116
# Answers: 59
#
# 7: [p9(X7)]
# min depth: 1
# Nodes: 100095
# Answers: 558
#
# 8: [p4(X6, X5)]
# min depth: 1
# Nodes: 100062
# Answers: 368
#
# 9: [p6(X0), p8(X0, X2, a98, X1), p7(X1), p1(a38, X2, X2), p2(a93, a29, X2)]
# min depth: 1
# Nodes: 100078
# Answers: 27
#
# 10: [p2(a32, X1, X0), p8(X0, X2, a69, a77), p5(a77, X1), p0(X2, X2), p0(X2, X2)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 11: [p5(a0, X8)]
# min depth: 1
# Nodes: 24
# Answers: 22
#
# 12: [p6(X0), p0(X0, a19), p8(X1, X0, a1, a12), p0(X1, a21)]
# min depth: 1
# Nodes: 100101
# Answers: 46
#
# 13: [p4(X8, X8)]
# Nodes: 100078
# Answers: 1
#
# 14: [p1(a23, X0, X0)]
# Restart...
# Restart...
# Answers: 0
#
# 15: [p9(X9)]
# min depth: 1
# Nodes: 100057
# Answers: 605
#
# 16: [p9(a90)]
# Restart...
# min depth: 2
# Nodes: 17581
# Answers: 4
#
# 17: [p1(a17, a28, X0), p5(X0, a15)]
# Nodes: 100109
# Answers: 1
#
# 18: [p1(X8, X5, X5)]
# min depth: 2
# Nodes: 100049
# Answers: 277
#
# 19: [p0(X6, X6)]
# Restart...
# min depth: 2
# Nodes: 100057
# Answers: 526
#
# 20: [p0(X8, X6)]
# min depth: 1
# Nodes: 32016
# Answers: 1000
#
# 21: [p8(a22, X0, a75, a3), p8(a19, X0, X0, a16)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 22: [p0(X7, X7)]
# min depth: 3
# Nodes: 100018
# Answers: 4
#
# 23: [p6(X1)]
# min depth: 1
# Nodes: 31423
# Answers: 27
#
# 24: [p9(X7)]
# min depth: 1
# Nodes: 100080
# Answers: 400
#
# 25: [p2(a93, X0, X1), p2(X2, a42, X0), p9(X1), p9(X2), p1(a38, a22, X1)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 26: [p0(X3, X3)]
# Restart...
# Restart...
# min depth: 2
# Nodes: 100041
# Answers: 30
#
# 27: [p1(a80, X2, X2)]
# Restart...
# min depth: 2
# Nodes: 50823
# Answers: 7
#
# 28: [p8(a7, a96, a30, X0), p9(X0), p6(X0)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 29: [p1(X0, a21, X1), p8(X0, a2, a56, a69), p0(X0, X1)]
# Nodes: 100160
# Answers: 1
#
# 30: [p9(X6)]
# min depth: 1
# Nodes: 100066
# Answers: 435
#
# 31: [p1(a39, X0, X0), p3(X0), p1(a93, a9, X0)]
# Restart...
# Restart...
# Answers: 0
#
# 32: [p4(X9, a53)]
# Restart...
# min depth: 4
# Nodes: 100080
# Answers: 58
#
# 33: [p1(X1, a0, X0), p1(a40, a15, X0), p2(X0, a52, X1)]
# min depth: 2
# Nodes: 71751
# Answers: 1000
#
# 34: [p1(X0, X9, X9)]
# min depth: 1
# Nodes: 100035
# Answers: 75
#
# 35: [p9(a90)]
# Restart...
# Restart...
# min depth: 2
# Nodes: 12244
# Answers: 2
#
# 36: [p5(X3, X0), p8(X0, X2, X1, X3), p8(X1, a75, a48, a1), p2(a1, X2, a91), p9(X3)]
# min depth: 1
# Nodes: 55
# Answers: 53
#
# 37: [p8(a24, X0, a69, a77), p1(X1, X0, X0), p5(X1, a86)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 38: [p2(X0, a1, X1), p6(X0)]
# Nodes: 100104
# Answers: 2
#
# 39: [p1(X0, a65, a0), p1(X0, a0, a0)]
# Nodes: 100116
# Answers: 1
#
# 40: [p1(X5, X7, X7)]
# min depth: 1
# Nodes: 27000
# Answers: 1000
#
# 41: [p9(a58)]
# min depth: 2
# Nodes: 44480
# Answers: 13
#
# 42: [p6(X0), p9(X0), p2(X1, X1, X0), p8(a90, a44, a87, X1)]
# min depth: 1
# Nodes: 100056
# Answers: 28
#
# 43: [p9(X4)]
# min depth: 1
# Nodes: 100094
# Answers: 787
#
# 44: [p9(X7)]
# min depth: 1
# Nodes: 100099
# Answers: 88
#
# 45: [p4(X0, X1), p0(X0, X0), p9(X1), p1(a28, X0, X0), p4(a35, X0)]
# min depth: 1
# Nodes: 4911
# Answers: 31
#
# 46: [p4(X0, X1), p4(X0, a48), p4(a38, X1)]
# min depth: 1
# Nodes: 48244
# Answers: 239
#
# 47: [p1(X3, X2, X2)]
# min depth: 1
# Nodes: 100059
# Answers: 433
#
# 48: [p8(a13, a0, a14, X0), p0(X0, X1), p1(X1, a65, a0)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 49: [p8(a20, a34, a68, X0), p1(X0, a26, a26)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 50: [p6(X2)]
# min depth: 1
# Nodes: 28035
# Answers: 66
#
# 51: [p1(a40, X3, X3)]
# Restart...
# Restart...
# Answers: 0
#
# 52: [p5(a85, X0), p0(X1, X0), p5(X1, a49)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 53: [p8(a19, X1, X0, X2), p5(X0, a33), p2(a12, a26, X1), p0(a45, X2)]
# min depth: 1
# Mismatched predicates: p5(X0, a33) with p2(a1, a19, X1)
# Nodes: 4
# Answers: 2
#
# 54: [p1(X7, X7, X7)]
# Restart...
# Restart...
# Answers: 0
#
# 55: [p6(X5)]
# min depth: 1
# Nodes: 28131
# Answers: 47
#
# 56: [p8(X0, X2, a29, a32), p5(X0, X1), p0(X0, X1), p2(a12, a12, X2)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 57: [p8(X0, X1, X2, a20), p9(X0), p9(X1), p5(X2, a0), p0(X1, X1)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 58: [p5(a18, X0), p8(a59, X0, a48, a1), p8(a22, a0, X0, a3)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 59: [p3(X0), p4(X0, a72)]
#  [-----] 0.0% to max nodes (307408 nps)Mismatched predicates: p4(X0, a72) with p8(X60, X60, X0, a0)
# min depth: 1
# Mismatched predicates: p4(X0, a72) with p8(X60, X60, X0, a0)
# Nodes: 6357
# Answers: 18
#
# 60: [p1(X9, X6, X6)]
# min depth: 4
# Nodes: 100049
# Answers: 192
#
# 61: [p0(X0, X1), p9(X0), p8(a19, a6, a24, X1)]
# min depth: 1
# Nodes: 100059
# Answers: 943
#
# 62: [p4(a34, X7)]
# min depth: 1
# Nodes: 3946
# Answers: 9
#
# 63: [p4(X0, X1), p0(X0, X0), p1(X2, X1, X3), p1(X2, X3, X3), p2(X3, a0, a31)]
# min depth: 1
# Nodes: 100090
# Answers: 92
#
# 64: [p0(X8, X8)]
# min depth: 5
# Nodes: 41770
# Answers: 1000
#
# 65: [p9(X0), p0(X0, X1), p1(X0, a64, a64), p0(X1, a15)]
# min depth: 1
# Nodes: 100076
# Answers: 308
#
# 66: [p1(a5, X5, X5)]
# Nodes: 100095
# Answers: 1
#
# 67: [p5(a24, X0), p0(X1, X0), p8(a73, X0, a10, a15), p4(X0, a56), p0(a55, X1)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 68: [p9(X3)]
# min depth: 1
# Nodes: 100071
# Answers: 179
#
# 69: [p1(X8, X4, X4)]
# min depth: 1
# Nodes: 7191
# Answers: 1
#
# 70: [p9(X7)]
# min depth: 1
# Nodes: 51557
# Answers: 1000
#
# 71: [p0(X3, X3)]
# Restart...
# min depth: 2
# Nodes: 100047
# Answers: 169
#
# 72: [p1(a17, X3, X3)]
# Restart...
# Restart...
# Answers: 0
#
# 73: [p5(X0, a40), p8(a32, X0, X1, a0), p2(X1, a0, X2), p8(X3, a32, X2, a46), p8(a79, a10, a26, X3)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 74: [p1(X4, X0, X0)]
# Nodes: 100105
# Answers: 1
#
# 75: [p0(X4, X4)]
# Restart...
# Restart...
# min depth: 8
# min depth: 4
# Nodes: 100071
# Answers: 490
#
# 76: [p6(a50)]
# Restart...
# min depth: 2
# Nodes: 100109
# Answers: 2
#
# 77: [p9(X0), p1(a56, X0, X0), p0(X0, X1), p0(X2, X1), p3(X2)]
# min depth: 2
# Nodes: 100066
# Answers: 81
#
# 78: [p6(X0), p9(X0), p8(X1, a15, a76, X0), p4(X1, a68), p1(a10, X0, a47)]
# min depth: 1
# Nodes: 100082
# Answers: 27
#
# 79: [p0(X1, X0), p6(X0), p0(a87, X1), p9(X0)]
# min depth: 1
# Nodes: 100060
# Answers: 236
#
# 80: [p9(X8)]
# min depth: 1
# Nodes: 100069
# Answers: 339
#
# 81: [p2(X0, a64, a27)]
# min depth: 1
# Nodes: 4
# Answers: 2
#
# 82: [p1(a1, X3, X3)]
# Nodes: 100165
# Answers: 1
#
# 83: [p6(a34)]
# min depth: 2
# Nodes: 4
# Answers: 1
#
# 84: [p0(X3, X3)]
# min depth: 2
# Nodes: 100062
# Answers: 112
#
# 85: [p1(a39, X6, X6)]
# Restart...
# Restart...
# min depth: 2
# Nodes: 6373
# Answers: 23
#
# 86: [p1(a52, X8, X8)]
# Restart...
# Restart...
# Answers: 0
#
# 87: [p4(X3, X4)]
# min depth: 1
# Nodes: 36683
# Answers: 28
#
# 88: [p6(X0), p8(X1, a34, X0, a63), p6(X1)]
# min depth: 1
# Nodes: 100071
# Answers: 44
#
# 89: [p6(a50)]
# min depth: 2
# Nodes: 4
# Answers: 1
#
# 90: [p1(X1, X0, X0), p1(X1, X0, X0), p1(X1, a12, X0), p1(X0, a70, a47), p2(X0, a53, a28)]
# min depth: 1
# Mismatched predicates: p1(X1, X0, X0) with p4(a27, a0)
#  [-----] 6.7% to max nodes (8944 nps)Mismatched predicates: p1(X1, X0, X0) with p4(a27, a0)
# Nodes: 100068
# Answers: 621
#
# 91: [p0(X3, X3)]
# min depth: 2
# Nodes: 100044
# Answers: 85
#
# 92: [p9(X1)]
# min depth: 1
# Nodes: 50203
# Answers: 1000
#
# 93: [p0(X5, X5)]
# min depth: 4
# Nodes: 100074
# Answers: 498
#
# 94: [p1(X3, a68, a68)]
# Restart...
# Restart...
# Answers: 0
#
# 95: [p9(X3)]
# min depth: 1
# Nodes: 77553
# Answers: 1000
#
# 96: [p9(X0)]
# min depth: 1
# Nodes: 100117
# Answers: 177
#
# 97: [p1(a13, X8, X8)]
# Restart...
# Restart...
# min depth: 4
# Nodes: 100075
# Answers: 3
#
# 98: [p0(X0, X0), p0(X0, X0), p1(a77, X0, X0)]
# Restart...
# min depth: 5
# Nodes: 100075
# Answers: 445
#
# 99: [p9(X5)]
# min depth: 1
# Nodes: 71563
# Answers: 1000
#
# 100: [p9(X1)]
# min depth: 1
# Nodes: 100054
# Answers: 248
#
# Before removing duplicates: 3869980 examples
# After removing duplicates: 172347 examples
# Replicating pos examples 44 times
# pos len=168647, neg len=168647

# %%
import sys
# !{sys.executable} ../nnreasoner.py --embed_type unification
# Out:
# States from vocab: vocab
# Num predicates: 10
# Max arity: 4
# Num constants: 100
# Num variables: 10
#
# Training unification
# Embed size: 50
# Reading examples from mr_train_examples.csv
# Parsing examples...
# Generating embeddings...
# Embedding input size: 450
#  [███████████████] 337293/337293 Prepping examples
# Loaded data...
# Using cuda device
# 0	0.18051 (-)
# 50	0.13889 (-0.0005)
# 100	0.13273 (-0.0003)
# 150	0.12809 (-0.0002)
# 200	0.12522 (-0.0002)
# 250	0.12304 (-0.0001)
# 300	0.12032 (-0.0001)
# 350	0.11836 (-0.0001)
# 400	0.11663 (-0.0001)
# 500	0.11343 (-0.0001)
# 550	0.11112 (-0.0001)
# 600	0.11020 (-9.8184)
# 650	0.10857 (-9.1964)
# 700	0.10734 (-8.7862)
# 749	0.10628 (-7.3456)
# Saved training loss figure.

# %%
import sys
print(sys.executable)
# Out:
# /opt/tljh/user/envs/cse327python311/bin/python

# %%
img = plt.imread('guided_loss-unification10-100-4-50.png')
plt. imshow(img)

# %%
# !{sys.executable}  ../evaluate.py --kb randomKB.txt -s
# !{sys.executable} ../evaluate.py --kb randomKB.txt -u
# Out:
# using cuda device
# STANDARD
#
# Query 1: [p0(X0, X0), p1(a56, X0, X0), p2(X0, a26, a6)]
# Query failed!!!
# 1000000 :: 0 - 00:01:43 (9684 nps)
#
# Query 2: [p8(a69, X0, a34, a24), p8(a0, X0, a76, a70)]
# 3 :: 2 - 00:00:00 (2606 nps)
#
# Query 3: [p2(a74, X0, a10), p1(a10, X0, X0)]
# Query failed!!!
# 1000000 :: 0 - 00:02:25 (6894 nps)
#
# Query 4: [p6(a60)]
# 3 :: 2 - 00:00:00 (7055 nps)
#
# Query 5: [p6(X5)]
# 2 :: 1 - 00:00:00 (6427 nps)
#
# Query 6: [p8(a90, a43, a95, X0), p8(a12, a42, a93, X0)]
# 3 :: 2 - 00:00:00 (2809 nps)
#
# Query 7: [p1(X1, a70, X0), p1(X1, X0, X0), p1(a93, a9, X1)]
# 9 :: 4 - 00:00:00 (3423 nps)
#
# Query 8: [p8(a5, a16, a82, X0), p1(a89, X0, X0)]
# 5 :: 3 - 00:00:00 (3577 nps)
#
# Query 9: [p0(X0, X0)]
# Query failed!!!
# 1000000 :: 0 - 00:01:33 (10675 nps)
#
# Query 10: [p1(a5, a20, X0), p2(X0, X1, a24), p8(X0, a36, a22, a0), p0(X1, X1), p8(a11, a60, X1, a99)]
# Query failed!!!
# 1000000 :: 0 - 00:02:35 (6424 nps)
#
# Query 11: [p0(X1, X1)]
# Query failed!!!
# 1000000 :: 0 - 00:01:32 (10791 nps)
#
# Query 12: [p1(X6, a0, a0)]
# 2 :: 1 - 00:00:00 (4602 nps)
#
# Query 13: [p0(X4, X4)]
# Query failed!!!
# 1000000 :: 0 - 00:01:32 (10758 nps)
#
# Query 14: [p9(a52)]
# Query failed!!!
# 1000000 :: 0 - 00:02:25 (6870 nps)
#
# Query 15: [p0(X1, X1)]
# Query failed!!!
# 1000000 :: 0 - 00:01:32 (10795 nps)
#
# Query 16: [p0(X7, X7)]
# Query failed!!!
# 1000000 :: 0 - 00:01:33 (10643 nps)
#
# Query 17: [p1(X0, X3, X3), p1(X0, X1, X3), p5(X2, X1), p1(a19, X2, X2), p1(X0, X3, X3)]
# 717612 :: 6 - 00:01:49 (6549 nps)
#
# Query 18: [p2(X2, X0, X1), p0(X0, X0), p0(X1, a86), p4(X0, a53), p5(X2, a27)]
# Query failed!!!
# 1000000 :: 0 - 00:02:21 (7068 nps)
#
# Query 19: [p6(X5)]
# 2 :: 1 - 00:00:00 (5276 nps)
#
# Query 20: [p1(a42, X5, X5)]
# 2753 :: 15 - 00:00:00 (3976 nps)
#
# Query 21: [p2(a93, X0, X1), p5(a90, X0), p4(X1, a0)]
# 4 :: 3 - 00:00:00 (3629 nps)
#
# Query 22: [p5(X0, a0), p0(X0, X1), p1(X2, X1, X1), p8(X1, a16, a0, a15), p1(X2, a0, X1)]
# Query failed!!!
# 1000000 :: 0 - 00:02:27 (6796 nps)
#
# Query 23: [p0(X2, X0), p8(a14, X1, a16, X0), p0(X2, a21)]
# 17 :: 3 - 00:00:00 (3097 nps)
#
# Query 24: [p1(a38, X2, X2)]
# 4 :: 2 - 00:00:00 (3785 nps)
#
# Query 25: [p8(X1, a33, X0, a15), p2(X0, a53, a28), p0(X1, a0), p1(a48, a12, X0)]
# 5 :: 4 - 00:00:00 (3551 nps)
#
# Query 26: [p9(X3)]
# 2 :: 1 - 00:00:00 (5832 nps)
#
# Query 27: [p9(X0), p8(a30, X0, X2, X1), p1(a45, X0, X0), p9(X1), p9(X2)]
# Query failed!!!
# 1000000 :: 0 - 00:02:37 (6364 nps)
#
# Query 28: [p1(a5, X1, X0), p6(X0), p4(X1, a90), p8(a0, a35, a29, X0)]
# 5 :: 4 - 00:00:00 (3276 nps)
#
# Query 29: [p1(X6, a31, a31)]
# 84 :: 2 - 00:00:00 (25803 nps)
#
# Query 30: [p9(X3)]
# 2 :: 1 - 00:00:00 (6089 nps)
#
# Query 31: [p0(X6, a1)]
# 27 :: 4 - 00:00:00 (4409 nps)
#
# Query 32: [p9(X0), p1(X0, X1, X1), p2(a1, X1, a27)]
# Query failed!!!
# 1000000 :: 0 - 00:02:08 (7811 nps)
#
# Query 33: [p9(X4)]
# 2 :: 1 - 00:00:00 (5398 nps)
#
# Query 34: [p8(X1, a0, a10, X0), p6(X0), p8(a10, a36, X1, a33)]
# 5 :: 4 - 00:00:00 (3331 nps)
#
# Query 35: [p4(X3, X7)]
# 2 :: 1 - 00:00:00 (4821 nps)
#
# Query 36: [p0(X0, X0), p1(X1, X0, X0), p1(X1, X0, X0), p8(X1, X2, a16, a33)]
# Query failed!!!
# 1000000 :: 0 - 00:01:55 (8688 nps)
#
# Query 37: [p1(X0, a0, a0)]
# 2 :: 1 - 00:00:00 (4881 nps)
#
# Query 38: [p6(X6)]
# 2 :: 1 - 00:00:00 (6178 nps)
#
# Query 39: [p1(a11, X0, X0)]
# Query failed!!!
# 1000000 :: 0 - 00:02:25 (6863 nps)
#
# Query 40: [p0(X0, X0), p0(a50, X0), p9(X0), p2(X1, X0, a14), p4(X1, a53)]
# Query failed!!!
# 1000000 :: 0 - 00:01:53 (8776 nps)
#
# Query 41: [p4(a39, X0), p0(X0, X0), p9(X0)]
# Query failed!!!
# 1000000 :: 0 - 00:02:06 (7926 nps)
#
# Query 42: [p4(X0, a23), p6(X0), p0(X0, X0)]
# 12 :: 6 - 00:00:00 (4308 nps)
#
# Query 43: [p1(X0, a0, a0), p8(X0, a2, X1, a69), p1(X1, a4, a4)]
# Query failed!!!
# 1000000 :: 0 - 00:02:37 (6354 nps)
#
# Query 44: [p1(X0, a80, a80), p0(X0, X0), p2(a7, a39, X0)]
# 73 :: 7 - 00:00:00 (13638 nps)
#
# Query 45: [p1(a3, X1, X1)]
# 4 :: 2 - 00:00:00 (3936 nps)
#
# Query 46: [p1(X1, X0, X0), p4(X0, X0), p0(X1, X1), p8(a59, a75, X2, X0), p0(X0, X2)]
# Query failed!!!
# 1000000 :: 0 - 00:02:43 (6127 nps)
#
# Query 47: [p9(X8)]
# 2 :: 1 - 00:00:00 (5776 nps)
#
# Query 48: [p8(a1, a58, X1, X0), p6(X0), p3(X1), p2(a19, a52, X1)]
# 5 :: 4 - 00:00:00 (3317 nps)
#
# Query 49: [p4(a0, X0), p1(a15, X0, X0), p0(X0, X0)]
# Query failed!!!
# 1000000 :: 0 - 00:02:28 (6749 nps)
#
# Query 50: [p1(X4, X8, X8)]
# 2 :: 1 - 00:00:00 (4082 nps)
#
# Query 51: [p6(X7)]
# 2 :: 1 - 00:00:00 (5652 nps)
#
# Query 52: [p9(X1)]
# 2 :: 1 - 00:00:00 (5729 nps)
#
# Query 53: [p9(X9)]
# 2 :: 1 - 00:00:00 (5996 nps)
#
# Query 54: [p2(a31, X0, X1), p0(X0, X0), p7(X0), p1(X1, X0, X0), p0(a29, X1)]
# Query failed!!!
# 1000000 :: 0 - 00:02:34 (6482 nps)
#
# Query 55: [p9(X9)]
# 2 :: 1 - 00:00:00 (5330 nps)
#
# Query 56: [p9(X4)]
# 2 :: 1 - 00:00:00 (6435 nps)
#
# Query 57: [p9(X1)]
# 2 :: 1 - 00:00:00 (6706 nps)
#
# Query 58: [p4(X4, X7)]
# 2 :: 1 - 00:00:00 (4781 nps)
#
# Query 59: [p8(X0, X1, a93, a49), p2(X0, X0, X2), p0(X1, X1), p8(a0, X2, a29, a32)]
# Query failed!!!
# 1000000 :: 0 - 00:02:22 (7033 nps)
#
# Query 60: [p4(X1, a53)]
# Query failed!!!
# 1000000 :: 0 - 00:02:17 (7294 nps)
#
# Query 61: [p0(X9, X9)]
# Query failed!!!
# 1000000 :: 0 - 00:01:36 (10391 nps)
#
# Query 62: [p0(X8, X8)]
# Query failed!!!
# 1000000 :: 0 - 00:01:38 (10198 nps)
#
# Query 63: [p9(X8)]
# 2 :: 1 - 00:00:00 (4744 nps)
#
# Query 64: [p0(X0, a49), p8(a20, X0, a68, a6), p8(a72, X0, X1, a0), p0(X1, a0)]
# 5 :: 4 - 00:00:00 (2709 nps)
#
# Query 65: [p0(X1, X6)]
# 2 :: 1 - 00:00:00 (3737 nps)
#
# Query 66: [p0(X0, a97), p6(X0)]
# 4 :: 3 - 00:00:00 (4700 nps)
#
# Query 67: [p5(X0, a1), p9(X0), p5(X0, a92)]
# Query failed!!!
# 1000000 :: 0 - 00:02:40 (6226 nps)
#
# Query 68: [p1(a5, X0, X0), p1(a5, a20, X0), p8(X0, a36, a22, a0)]
# 6 :: 4 - 00:00:00 (3098 nps)
#
# Query 69: [p9(X2)]
# 2 :: 1 - 00:00:00 (5317 nps)
#
# Query 70: [p0(a0, a68)]
# 6 :: 5 - 00:00:00 (4396 nps)
#
# Query 71: [p1(X0, a29, a29), p8(a8, X0, a98, X1), p8(a19, a0, a0, X1)]
# Query failed!!!
# 1000000 :: 0 - 00:02:48 (5937 nps)
#
# Query 72: [p4(X0, X2)]
# 2 :: 1 - 00:00:00 (4106 nps)
#
# Query 73: [p1(X8, a0, a0)]
# 2 :: 1 - 00:00:00 (4767 nps)
#
# Query 74: [p1(X5, X3, X3)]
# 2 :: 1 - 00:00:00 (4252 nps)
#
# Query 75: [p8(X1, X0, a30, a32), p9(X0), p5(a12, X1), p8(a0, X1, a76, a70)]
# 6 :: 5 - 00:00:00 (3085 nps)
#
# Query 76: [p1(a56, X3, X3)]
# 4 :: 2 - 00:00:00 (3226 nps)
#
# Query 77: [p4(X2, a53)]
# Query failed!!!
# 1000000 :: 0 - 00:02:25 (6883 nps)
#
# Query 78: [p9(X6)]
# 2 :: 1 - 00:00:00 (5338 nps)
#
# Query 79: [p1(X0, a23, a23), p8(X1, a68, a69, X0), p8(a8, X1, a98, a16)]
# Query failed!!!
# 1000000 :: 0 - 00:02:49 (5887 nps)
#
# Query 80: [p6(X0), p7(X0)]
# 4 :: 2 - 00:00:00 (5843 nps)
#
# Query 81: [p9(X8)]
# 2 :: 1 - 00:00:00 (5822 nps)
#
# Query 82: [p0(X1, X1)]
# Query failed!!!
# 1000000 :: 0 - 00:01:39 (10088 nps)
#
# Query 83: [p6(X5)]
# 2 :: 1 - 00:00:00 (5170 nps)
#
# Query 84: [p1(a29, X7, X7)]
# Query failed!!!
# 1000000 :: 0 - 00:02:33 (6500 nps)
#
# Query 85: [p0(X1, X1)]
# Query failed!!!
# 1000000 :: 0 - 00:01:37 (10249 nps)
#
# Query 86: [p0(a10, X0)]
# 2 :: 1 - 00:00:00 (3604 nps)
#
# Query 87: [p9(X7)]
# 2 :: 1 - 00:00:00 (5548 nps)
#
# Query 88: [p1(a19, X7, X7)]
# 4 :: 2 - 00:00:00 (3537 nps)
#
# Query 89: [p9(X0)]
# 2 :: 1 - 00:00:00 (5836 nps)
#
# Query 90: [p0(X5, X5)]
# Query failed!!!
# 1000000 :: 0 - 00:01:40 (9990 nps)
#
# Query 91: [p8(X0, a68, a69, a77), p2(a3, X0, a8)]
# 3 :: 2 - 00:00:00 (3109 nps)
#
# Query 92: [p1(X4, X0, X0)]
# 2 :: 1 - 00:00:00 (4148 nps)
#
# Query 93: [p6(X1)]
# 2 :: 1 - 00:00:00 (5734 nps)
#
# Query 94: [p0(X4, X4)]
# Query failed!!!
# 1000000 :: 0 - 00:01:38 (10107 nps)
#
# Query 95: [p1(X0, X1, X1), p0(X0, X1), p8(X1, a49, a66, a46)]
# Query failed!!!
# 1000000 :: 0 - 00:02:51 (5836 nps)
#
# Query 96: [p1(a5, X0, X0), p8(X0, a11, a0, a87)]
# 5 :: 3 - 00:00:00 (3172 nps)
#
# Query 97: [p4(X7, X2)]
# 2 :: 1 - 00:00:00 (4789 nps)
#
# Query 98: [p4(X1, X0), p9(X0), p8(a84, X2, a44, X1), p8(a32, X0, a22, a0), p0(X2, a49)]
# Query failed!!!
# 1000000 :: 0 - 00:02:44 (6083 nps)
#
# Query 99: [p9(X4)]
# 2 :: 1 - 00:00:00 (5456 nps)
#
# Query 100: [p8(a80, a46, X0, a20), p8(X0, a75, a48, a1)]
# 3 :: 2 - 00:00:00 (3026 nps)
#
# std: 367207.51 nodes/query
# 36 queries failed
# Time to run all queries: 4826.261776474998
# using cuda device
# UNITY: ming
# 	Embedding Model: rKB_model.pth
# 	Scoring Model: uni_mr_model.pt
#
# 	Control: mingoal
# 	Rule Eval: Max Rule
# Learned Embedding: Network using cuda
# Query 1: [p0(X0, X0), p1(a56, X0, X0), p2(X0, a26, a6)]
# 6 :: 5 - 00:00:00 (45 nps)
#
# Query 2: [p8(a69, X0, a34, a24), p8(a0, X0, a76, a70)]
# 3 :: 2 - 00:00:00 (785 nps)
#
# Query 3: [p2(a74, X0, a10), p1(a10, X0, X0)]
# 29 :: 15 - 00:00:00 (114 nps)
#
# Query 4: [p6(a60)]
# 3 :: 2 - 00:00:00 (824 nps)
#
# Query 5: [p6(X5)]
# 2 :: 1 - 00:00:00 (96 nps)
#
# Query 6: [p8(a90, a43, a95, X0), p8(a12, a42, a93, X0)]
# 3 :: 2 - 00:00:00 (701 nps)
#
# Query 7: [p1(X1, a70, X0), p1(X1, X0, X0), p1(a93, a9, X1)]
# 55011 :: 4 - 00:00:27 (1999 nps)
#
# Query 8: [p8(a5, a16, a82, X0), p1(a89, X0, X0)]
# 16581 :: 3 - 00:00:07 (2305 nps)
#
# Query 9: [p0(X0, X0)]
# 3 :: 2 - 00:00:00 (99 nps)
#
# Query 10: [p1(a5, a20, X0), p2(X0, X1, a24), p8(X0, a36, a22, a0), p0(X1, X1), p8(a11, a60, X1, a99)]
# 7 :: 6 - 00:00:00 (126 nps)
#
# Query 11: [p0(X1, X1)]
# 4 :: 3 - 00:00:00 (140 nps)
#
# Query 12: [p1(X6, a0, a0)]
# 2 :: 1 - 00:00:00 (319 nps)
#
# Query 13: [p0(X4, X4)]
# 3 :: 2 - 00:00:00 (98 nps)
#
# Query 14: [p9(a52)]
# 30 :: 15 - 00:00:00 (134 nps)
#
# Query 15: [p0(X1, X1)]
# 4 :: 3 - 00:00:00 (26358 nps)
#
# Query 16: [p0(X7, X7)]
# 3 :: 2 - 00:00:00 (98 nps)
#
# Query 17: [p1(X0, X3, X3), p1(X0, X1, X3), p5(X2, X1), p1(a19, X2, X2), p1(X0, X3, X3)]
# 6 :: 5 - 00:00:00 (34 nps)
#
# Query 18: [p2(X2, X0, X1), p0(X0, X0), p0(X1, a86), p4(X0, a53), p5(X2, a27)]
# 150776 :: 13 - 00:01:14 (2033 nps)
#
# Query 19: [p6(X5)]
# 2 :: 1 - 00:00:00 (93 nps)
#
# Query 20: [p1(a42, X5, X5)]
# 49 :: 15 - 00:00:00 (168 nps)
#
# Query 21: [p2(a93, X0, X1), p5(a90, X0), p4(X1, a0)]
# 4 :: 3 - 00:00:00 (406 nps)
#
# Query 22: [p5(X0, a0), p0(X0, X1), p1(X2, X1, X1), p8(X1, a16, a0, a15), p1(X2, a0, X1)]
# 178946 :: 6 - 00:00:33 (5274 nps)
#
# Query 23: [p0(X2, X0), p8(a14, X1, a16, X0), p0(X2, a21)]
# 4 :: 3 - 00:00:00 (82 nps)
#
# Query 24: [p1(a38, X2, X2)]
# 50 :: 15 - 00:00:00 (173 nps)
#
# Query 25: [p8(X1, a33, X0, a15), p2(X0, a53, a28), p0(X1, a0), p1(a48, a12, X0)]
# 5 :: 4 - 00:00:00 (162 nps)
#
# Query 26: [p9(X3)]
# 2 :: 1 - 00:00:00 (91 nps)
#
# Query 27: [p9(X0), p8(a30, X0, X2, X1), p1(a45, X0, X0), p9(X1), p9(X2)]
# 27328 :: 15 - 00:00:10 (2731 nps)
#
# Query 28: [p1(a5, X1, X0), p6(X0), p4(X1, a90), p8(a0, a35, a29, X0)]
# 5 :: 4 - 00:00:00 (97 nps)
#
# Query 29: [p1(X6, a31, a31)]
# 3 :: 2 - 00:00:00 (259 nps)
#
# Query 30: [p9(X3)]
# 2 :: 1 - 00:00:00 (26217 nps)
#
# Query 31: [p0(X6, a1)]
# 4 :: 2 - 00:00:00 (367 nps)
#
# Query 32: [p9(X0), p1(X0, X1, X1), p2(a1, X1, a27)]
# 79008 :: 6 - 00:00:20 (3873 nps)
#
# Query 33: [p9(X4)]
# 2 :: 1 - 00:00:00 (98 nps)
#
# Query 34: [p8(X1, a0, a10, X0), p6(X0), p8(a10, a36, X1, a33)]
# 5 :: 4 - 00:00:00 (463 nps)
#
# Query 35: [p4(X3, X7)]
# 2 :: 1 - 00:00:00 (93 nps)
#
# Query 36: [p0(X0, X0), p1(X1, X0, X0), p1(X1, X0, X0), p8(X1, X2, a16, a33)]
# 154 :: 15 - 00:00:01 (133 nps)
#
# Query 37: [p1(X0, a0, a0)]
# 2 :: 1 - 00:00:00 (326 nps)
#
# Query 38: [p6(X6)]
# 2 :: 1 - 00:00:00 (98 nps)
#
# Query 39: [p1(a11, X0, X0)]
# 38620 :: 3 - 00:00:10 (3736 nps)
#
# Query 40: [p0(X0, X0), p0(a50, X0), p9(X0), p2(X1, X0, a14), p4(X1, a53)]
# 9650 :: 9 - 00:00:04 (2247 nps)
#
# Query 41: [p4(a39, X0), p0(X0, X0), p9(X0)]
# 177906 :: 8 - 00:00:55 (3177 nps)
#
# Query 42: [p4(X0, a23), p6(X0), p0(X0, X0)]
# 5 :: 4 - 00:00:00 (116 nps)
#
# Query 43: [p1(X0, a0, a0), p8(X0, a2, X1, a69), p1(X1, a4, a4)]
# 10594 :: 5 - 00:00:04 (2156 nps)
#
# Query 44: [p1(X0, a80, a80), p0(X0, X0), p2(a7, a39, X0)]
# 18203 :: 7 - 00:00:04 (4471 nps)
#
# Query 45: [p1(a3, X1, X1)]
# 3 :: 2 - 00:00:00 (255 nps)
#
# Query 46: [p1(X1, X0, X0), p4(X0, X0), p0(X1, X1), p8(a59, a75, X2, X0), p0(X0, X2)]
# 1350 :: 15 - 00:00:03 (422 nps)
#
# Query 47: [p9(X8)]
# 2 :: 1 - 00:00:00 (99 nps)
#
# Query 48: [p8(a1, a58, X1, X0), p6(X0), p3(X1), p2(a19, a52, X1)]
# 5 :: 4 - 00:00:00 (139 nps)
#
# Query 49: [p4(a0, X0), p1(a15, X0, X0), p0(X0, X0)]
# 26062 :: 7 - 00:00:05 (5178 nps)
#
# Query 50: [p1(X4, X8, X8)]
# 2 :: 1 - 00:00:00 (259 nps)
#
# Query 51: [p6(X7)]
# 2 :: 1 - 00:00:00 (97 nps)
#
# Query 52: [p9(X1)]
# 2 :: 1 - 00:00:00 (97 nps)
#
# Query 53: [p9(X9)]
# 2 :: 1 - 00:00:00 (97 nps)
#
# Query 54: [p2(a31, X0, X1), p0(X0, X0), p7(X0), p1(X1, X0, X0), p0(a29, X1)]
# 27858 :: 14 - 00:00:07 (3939 nps)
#
# Query 55: [p9(X9)]
# 2 :: 1 - 00:00:00 (21298 nps)
#
# Query 56: [p9(X4)]
# 2 :: 1 - 00:00:00 (96 nps)
#
# Query 57: [p9(X1)]
# 2 :: 1 - 00:00:00 (24650 nps)
#
# Query 58: [p4(X4, X7)]
# 2 :: 1 - 00:00:00 (94 nps)
#
# Query 59: [p8(X0, X1, a93, a49), p2(X0, X0, X2), p0(X1, X1), p8(a0, X2, a29, a32)]
# 6 :: 5 - 00:00:00 (249 nps)
#
# Query 60: [p4(X1, a53)]
# 6 :: 5 - 00:00:00 (77 nps)
#
# Query 61: [p0(X9, X9)]
# 3 :: 2 - 00:00:00 (99 nps)
#
# Query 62: [p0(X8, X8)]
# 3 :: 2 - 00:00:00 (84 nps)
#
# Query 63: [p9(X8)]
# 2 :: 1 - 00:00:00 (24021 nps)
#
# Query 64: [p0(X0, a49), p8(a20, X0, a68, a6), p8(a72, X0, X1, a0), p0(X1, a0)]
# 5 :: 4 - 00:00:00 (135 nps)
#
# Query 65: [p0(X1, X6)]
# 2 :: 1 - 00:00:00 (76 nps)
#
# Query 66: [p0(X0, a97), p6(X0)]
# Query failed!!!
# 1000000 :: 0 - 00:05:25 (3071 nps)
#
# Query 67: [p5(X0, a1), p9(X0), p5(X0, a92)]
# 89376 :: 4 - 00:00:13 (6539 nps)
#
# Query 68: [p1(a5, X0, X0), p1(a5, a20, X0), p8(X0, a36, a22, a0)]
# 5 :: 4 - 00:00:00 (139 nps)
#
# Query 69: [p9(X2)]
# 2 :: 1 - 00:00:00 (90 nps)
#
# Query 70: [p0(a0, a68)]
# 6 :: 5 - 00:00:00 (223 nps)
#
# Query 71: [p1(X0, a29, a29), p8(a8, X0, a98, X1), p8(a19, a0, a0, X1)]
# 29 :: 15 - 00:00:00 (228 nps)
#
# Query 72: [p4(X0, X2)]
# 2 :: 1 - 00:00:00 (89 nps)
#
# Query 73: [p1(X8, a0, a0)]
# 2 :: 1 - 00:00:00 (321 nps)
#
# Query 74: [p1(X5, X3, X3)]
# 2 :: 1 - 00:00:00 (264 nps)
#
# Query 75: [p8(X1, X0, a30, a32), p9(X0), p5(a12, X1), p8(a0, X1, a76, a70)]
# 6 :: 5 - 00:00:00 (164 nps)
#
# Query 76: [p1(a56, X3, X3)]
# 3 :: 2 - 00:00:00 (216 nps)
#
# Query 77: [p4(X2, a53)]
# 5 :: 4 - 00:00:00 (64 nps)
#
# Query 78: [p9(X6)]
# 2 :: 1 - 00:00:00 (90 nps)
#
# Query 79: [p1(X0, a23, a23), p8(X1, a68, a69, X0), p8(a8, X1, a98, a16)]
# 7 :: 6 - 00:00:00 (197 nps)
#
# Query 80: [p6(X0), p7(X0)]
# 4 :: 3 - 00:00:00 (103 nps)
#
# Query 81: [p9(X8)]
# 2 :: 1 - 00:00:00 (95 nps)
#
# Query 82: [p0(X1, X1)]
# 4 :: 3 - 00:00:00 (117 nps)
#
# Query 83: [p6(X5)]
# 2 :: 1 - 00:00:00 (91 nps)
#
# Query 84: [p1(a29, X7, X7)]
# 10 :: 9 - 00:00:00 (233 nps)
#
# Query 85: [p0(X1, X1)]
# 4 :: 3 - 00:00:00 (26918 nps)
#
# Query 86: [p0(a10, X0)]
# 2 :: 1 - 00:00:00 (331 nps)
#
# Query 87: [p9(X7)]
# 2 :: 1 - 00:00:00 (94 nps)
#
# Query 88: [p1(a19, X7, X7)]
# 3 :: 2 - 00:00:00 (254 nps)
#
# Query 89: [p9(X0)]
# 2 :: 1 - 00:00:00 (23794 nps)
#
# Query 90: [p0(X5, X5)]
# 4 :: 3 - 00:00:00 (123 nps)
#
# Query 91: [p8(X0, a68, a69, a77), p2(a3, X0, a8)]
# 3 :: 2 - 00:00:00 (735 nps)
#
# Query 92: [p1(X4, X0, X0)]
# 2 :: 1 - 00:00:00 (255 nps)
#
# Query 93: [p6(X1)]
# 2 :: 1 - 00:00:00 (96 nps)
#
# Query 94: [p0(X4, X4)]
# 3 :: 2 - 00:00:00 (93 nps)
#
# Query 95: [p1(X0, X1, X1), p0(X0, X1), p8(X1, a49, a66, a46)]
# 243533 :: 6 - 00:01:11 (3411 nps)
#
# Query 96: [p1(a5, X0, X0), p8(X0, a11, a0, a87)]
# 4 :: 3 - 00:00:00 (225 nps)
#
# Query 97: [p4(X7, X2)]
# 2 :: 1 - 00:00:00 (92 nps)
#
# Query 98: [p4(X1, X0), p9(X0), p8(a84, X2, a44, X1), p8(a32, X0, a22, a0), p0(X2, a49)]
# 13446 :: 6 - 00:00:08 (1611 nps)
#
# Query 99: [p9(X4)]
# 2 :: 1 - 00:00:00 (95 nps)
#
# Query 100: [p8(a80, a46, X0, a20), p8(X0, a75, a48, a1)]
# 3 :: 2 - 00:00:00 (690 nps)
#
# ming: 21648.42 nodes/query
# 1 queries failed
# Time to run all queries: 691.2954819860001

# %%
# !ls *.csv
# Out:
# ming-10-100-4-50.csv  mr_train_examples.csv  std-10-100-4-50.csv  triplets.csv

# %%
# !head std-10-100-4-50.csv 
# !head ming-10-100-4-50.csv
# Out:
# query,std reasoner,std nodes explored,std min depth,success,time
# 1,std,1000000,0,False,103.258242825
# 2,std,3,2,True,0.001151180000007912
# 3,std,1000000,0,False,145.03528826800004
# 4,std,3,2,True,0.0004252090000136377
# 5,std,2,1,True,0.0003111490000264894
# 6,std,3,2,True,0.0010679470000241054
# 7,std,9,4,True,0.002629055999989305
# 8,std,5,3,True,0.0013977629999999408
# 9,std,1000000,0,False,93.66993271199999
# query,ming reasoner,ming nodes explored,ming min depth,success,time
# 1,ming,6,5,True,0.13212924900000012
# 2,ming,3,2,True,0.0038195180000002438
# 3,ming,29,15,True,0.2531907579999988
# 4,ming,3,2,True,0.003636733000000447
# 5,ming,2,1,True,0.02080457000000102
# 6,ming,3,2,True,0.004276438999999854
# 7,ming,55011,4,True,27.509066681
# 8,ming,16581,3,True,7.191071796000003
# 9,ming,3,2,True,0.030017518000001076
