# %% [markdown]
# The block below imports a necessary module and checks if you are in the right directory. If you do not see a list of python files when you run the block, please make sure you have uploaded the zip file and unzipped it.

# %%
import matplotlib.pyplot as plt

# %pwd
# %ls
# Out:
#  all_facts.txt             nnreasoner.py
#  atomgenerator.py          nnunifier.py
#  autoencoder.py            prints.cpython-311.pyc
#  basictypes.py             __pycache__/
#  chainbased.py             randomKB.txt
# 'CSE 327 P4-Copy1.ipynb'   reasoner.py
# 'CSE 327 P4.ipynb'         rKB_model.pth
#  embedmodel.py             termwalk.py
#  evaluate.py               test_queries.txt
#  gameofthrones.txt         training_and_validation_loss.png
#  gen_queries.py            training_loss-10-100-4-50.png
#  helpers/                  training_loss-10-100-5-50.png
#  kbencoder.py              train_queries.txt
#  kbparser.py               triplets.csv
#  knowledgebase.py          Untitled.ipynb
#  mr_back_reasoner.py       vocab.pkl
#  mr_train_examples.csv     vocab.py

# %%
import sys
print(sys.executable)
# Out:
# /opt/tljh/user/envs/cse327python311/bin/python

# %% [markdown]
# If you want to create a random knowledge base, run the following code.
#
# Creates the files:
#
# * randomKB.txt - A random KB generated using 10 predicates and 100 constants.
# * vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !{sys.executable} kbencoder.py --generate_kb --new_vocab --save_vocab
# !head randomKB.txt
# Out:
# Classes: 100000000000.0
# Max arity: 5
# KB generated (150)
# p7(a23, a47, a45, a90).
# p7(a12, a64, a33, a10).
# p9(a2, a69).
# p7(a47, a16, a39, a1).
# p7(a31, a72, a83, a42).
# p7(a4, a94, a50, a3).
# p6(a0, a10).
# p0(a12, a55).
# p2(a1, a89, a78, a58, a83).
# p4(a72, a61, a59, a44, a40).

# %% [markdown]
# The following code prepares an existing knowledge base (KB) for use. To use a KB of your choosing, replace gameofthrones.txt with the file name of any KB you want to use.
#
# Creates the file:
#
# *   vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
import sys
# !{sys.executable} kbencoder.py --kb_path gameofthrones.txt --vocab_from_kb --save_vocab
# Out:
# Creating vocabulary from last gameofthrones.txt knowledge base

# %% [markdown]
# Train a neural net to convert first-order logic atoms into meaningful numeric vectors. We call these vectors "embeddings," and the learned model the embedding model. The code creates random atoms and then uses a mechanism known as triplet loss to place unifying atoms closer together.
#
# Creates the files:
#
# *   rKB_model.pth - Saves the learned weights for the embedding model
# *   training_loss-45-106-2-50.png - A plot of the training loss after each epoch. This file's name depends on the vocabulary of your KB: the four numbers are number of predicates, number of constants, max arity of the predicates, and the embedding size used. If you changed the KB, you'll need to look up the name in your drive and update the code block that displays this file.

# %%
import sys
# !{sys.executable} kbencoder.py --kb_path gameofthrones.txt --train_unification_model
# Out:
# Using cuda device
# Uni model embed size: 50
#  [████████████████████] 3500/3500 Anchors generated
#  [████████████████████] 70000/70000 Triplets generated
#  [█████---------------] 18445/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [██████████████------] 49718/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [████████████████████] 70000/70000 Triplet encodings
# Early stopping triggered-------------] 40.7% Epoch | [Epoch 204/500, Training Loss: 0.0367, Validation Loss: 0.3011]
# Saved model.
# Saved plot.
# unification model generated

# %%
import glob
glob.glob('training_loss*.png')
# Out:
# ['training_loss-10-100-5-50.png',
#  'training_loss-45-106-2-50.png',
#  'training_loss-10-100-4-50.png']

# %%
img = plt.imread('training_loss-45-106-2-50.png')
plt. imshow(img)

# %% [markdown]
# Generate a set of train and test queries from your knowledge base. This will also generate the deductive closure (all facts that can be inferred) of your KB using forward-chaining.
#
# Produces the files:
#
# *  all_facts.txt - A list of all facts that can be inferred from the KB. This is used to generate queries that are guaranteed to have an answer.
# *  train_queries.txt - A set of training queries where each will have at least one answer.
# *  test_queries.txt - A set of test queries where each will have at least one answer.

# %%
import sys
# !{sys.executable} kbencoder.py --kb_path gameofthrones.txt -g
# Out:
# Generating facts list...
# Forward chaining depth: 1
# New facts: 442
# Forward chaining depth: 2
# New facts: 175
# Forward chaining depth: 3
# New facts: 82
# Forward chaining depth: 4
# New facts: 12
# Forward chaining depth: 5
# New facts: 1
# Forward chaining depth: 6
# New facts: 2
# Forward chaining depth: 7
#
# Facts list generated
# 714 total facts. Max depth = 6
#
# Number of queries: 200
# 100 training queries generated
# 100 testing queries generated

# %% [markdown]
# Create a training set for the scoring model. The examples will consist of goal, rule, score pairs, where a score of 1 means the rule can solve the goal, and 0 means it cannot. It runs the full set of training queries with a randomized backward-chaining process. This step can sometimes take a long time and is not able to take advantage of a GPU (with the gameofthrones KB it took ~45 minutes).
#
# Creates a file:
# *  mr_train_examples.csv - Contains a line for each goal/rule/score example.

# %%
import sys
# !{sys.executable}  kbencoder.py --kb_path gameofthrones.txt -p
# Out:
# running training queries...
# Negative facts will be generated
# 1: [ancestor(_EX4, X)]
# min depth: 2
# Nodes: 1644
# Answers: 220
#
# 2: [ancestor(Z, X), parent(Y, X), ancestor(Y, _EX0), parent(Z, X), descendant(_EX0, Y)]
# Restart...
# min depth: 2
# Nodes: 79516
# Answers: 174
#
# 3: [descendant(X, tytos_lannister), father(X, tommen_lannister)]
# min depth: 5
# Nodes: 47206
# Answers: 38
#
# 4: [parent(X, Z), ancestor(X, Y), parent(X, Y), daughter(Y, rhaegar_targaryen), parent(rhaegar_targaryen, Z)]
# min depth: 1
# Nodes: 105
# Answers: 104
#
# 5: [status(Y, X), status(olenna_tyrell, X)]
# min depth: 1
# Nodes: 80
# Answers: 79
#
# 6: [son(_EX0, alannys_harlaw)]
# min depth: 3
# Nodes: 9
# Answers: 3
#
# 7: [parent(Y, X), descendant(X, Y), child(X, Y), parent(Y, Z), child(Z, Y)]
# min depth: 1
# Nodes: 105
# Answers: 104
#
# 8: [child(Z, _EX2)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 9: [descendant(theon_greyjoy, X), ancestor(X, Y), female(X), child(Y, X)]
# Restart...
# Restart...
# min depth: 3
# Nodes: 14432
# Answers: 8
#
# 10: [descendant(jaime_lannister, _EX0)]
# Restart...
# min depth: 3
# Nodes: 9338
# Answers: 8
#
# 11: [child(_EX4, _EX0)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 12: [parent(steffon_baratheon, X), parent(Y, X), status(Y, dead)]
# min depth: 1
# Nodes: 4
# Answers: 3
#
# 13: [female(X), ancestor(X, nymeria_sand), child(nymeria_sand, X), descendant(nymeria_sand, X), parent(X, nymeria_sand)]
# min depth: 1
# Nodes: 33
# Answers: 32
#
# 14: [ancestor(unknown_mother_lannister, X), child(X, Y), parent(Y, X), love(jamie_lannister, Y)]
# min depth: 2
# Nodes: 23000
# Answers: 21
#
# 15: [descendant(tommen_lannister, _EX5)]
# min depth: 5
# Nodes: 43627
# Answers: 18
#
# 16: [creatures(X), magic_ressurrected(X), status(X, alive)]
# min depth: 2
# Nodes: 9
# Answers: 5
#
# 17: [descendant(_EX3, _EX5)]
# Restart...
# Restart...
# Answers: 0
#
# 18: [parent(balon_greyjoy, X), son(X, Y), ancestor(Y, X), status(X, dead)]
# min depth: 1
# Nodes: 5
# Answers: 4
#
# 19: [mother(unknown_mother_targaryen, X)]
# min depth: 3
# Nodes: 7
# Answers: 4
#
# 20: [descendant(_EX1, _EX4)]
# Restart...
# min depth: 5
# Nodes: 16224
# Answers: 198
#
# 21: [son(_EX0, _EX3)]
# min depth: 3
# Nodes: 178
# Answers: 72
#
# 22: [ancestor(_EX2, X)]
# min depth: 2
# Nodes: 100149
# Answers: 112
#
# 23: [descendant(_EX6, lewyn_martell)]
# min depth: 3
# Nodes: 2044
# Answers: 8
#
# 24: [ancestor(_EX3, sansa_stark)]
# Restart...
# min depth: 4
# Nodes: 30612
# Answers: 10
#
# 25: [mother(X, Y), status(X, dead), female(X), child(Y, eddard_stark)]
# min depth: 3
# Nodes: 155
# Answers: 49
#
# 26: [descendant(X, Y), parent(Y, X), mother(Y, theon_greyjoy), mother(Y, X)]
# min depth: 3
# Nodes: 1596
# Answers: 238
#
# 27: [descendant(bran_stark, Y)]
# Restart...
# min depth: 3
# Nodes: 12726
# Answers: 8
#
# 28: [child(_EX3, _EX5)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 29: [descendant(_EX6, _EX0)]
# min depth: 3
# Nodes: 46002
# Answers: 232
#
# 30: [descendant(_EX4, _EX5)]
# Restart...
# Restart...
# Answers: 0
#
# 31: [child(robert_baratheon, _EX4)]
# min depth: 2
# Nodes: 4
# Answers: 2
#
# 32: [descendant(Z, X)]
# min depth: 3
# Nodes: 44051
# Answers: 168
#
# 33: [ancestor(Y, X), child(Z, X), parent(Y, _EX0), who_killed_daenerys(Z), take_away(drogon, _EX0)]
# Restart...
# min depth: 2
# Nodes: 100198
# Answers: 121
#
# 34: [status(X, alive)]
# min depth: 1
# Nodes: 17
# Answers: 16
#
# 35: [descendant(_EX0, tywin_lannister)]
# min depth: 3
# Nodes: 2706
# Answers: 12
#
# 36: [child(_EX4, _EX2)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 37: [who_loved_daenerys(_EX2)]
# min depth: 2
# Nodes: 7
# Answers: 5
#
# 38: [parent(X, stannis_baratheon), descendant(stannis_baratheon, X)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 39: [ancestor(Y, Z)]
# min depth: 2
# Nodes: 100255
# Answers: 126
#
# 40: [descendant(bran_stark, _EX6)]
# min depth: 5
# Nodes: 56638
# Answers: 4
#
# 41: [mother(Y, _EX2)]
# min depth: 3
# Nodes: 155
# Answers: 49
#
# 42: [son(_EX2, kevan_lannister)]
# min depth: 3
# Nodes: 52
# Answers: 3
#
# 43: [ancestor(_EX0, _EX1)]
# Restart...
# min depth: 2
# Nodes: 100180
# Answers: 118
#
# 44: [son(X, Y), male(X), ancestor(Y, rhaenys_targaryen), ancestor(Z, X), ancestor(Z, daenerys_targaryen)]
# min depth: 3
# Nodes: 121
# Answers: 72
#
# 45: [ancestor(aegon_v_targaryen, jon_snow)]
# Restart...
# Restart...
# Answers: 0
#
# 46: [ancestor(_EX6, _EX5)]
# min depth: 2
# Nodes: 24216
# Answers: 214
#
# 47: [ancestor(_EX3, ella_martell)]
# Restart...
# min depth: 2
# Nodes: 9191
# Answers: 2
#
# 48: [ancestor(X, Z), descendant(Y, X), descendant(arya_stark, X), ancestor(X, Y), ancestor(catelyn_stark, Z)]
# min depth: 2
# Nodes: 54114
# Answers: 218
#
# 49: [ancestor(aegon_v_targaryen, Z)]
# min depth: 2
# Nodes: 3520
# Answers: 4
#
# 50: [child(X, unknown_mother_targaryen), parent(aegon_v_targaryen, X)]
# min depth: 2
# Nodes: 6
# Answers: 4
#
# 51: [descendant(_EX1, unknown_mother_lannister)]
# min depth: 3
# Nodes: 21741
# Answers: 15
#
# 52: [ancestor(_EX6, doran_martell)]
# min depth: 2
# Nodes: 100058
# Answers: 2
#
# 53: [ancestor(balon_greyjoy, _EX5)]
# min depth: 2
# Nodes: 13
# Answers: 4
#
# 54: [descendant(Z, _EX5)]
# min depth: 7
# Nodes: 100193
# Answers: 32
#
# 55: [parent(X, loras_tyrell), daughter(Y, X), descendant(Y, X), child(Y, X), son(loras_tyrell, X)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 56: [status(X, dead), father(luthor_tyrell, X)]
# min depth: 1
# Nodes: 64
# Answers: 63
#
# 57: [status(the_hound, X), status(Y, X), descendant(Y, unknown_father_greyjoy)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 58: [betray(X, daenerys_targaryen), kill(Y, X), dragon(Y), destroy(Y, Z), destroy(daenerys_targaryen, Z)]
# min depth: 1
# Nodes: 6
# Answers: 5
#
# 59: [love(hizdahr_zo_loraq, X), betray(varys, X)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 60: [child(_EX1, _EX0)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 61: [descendant(obara_sand, X), daughter(obara_sand, X), ancestor(X, obara_sand)]
# min depth: 3
# Nodes: 4789
# Answers: 4
#
# 62: [parent(X, Y), ancestor(X, Z), father(X, Y), father(rhaegar_targaryen, Z), ancestor(X, aerys_targaryen)]
# min depth: 1
# Nodes: 105
# Answers: 104
#
# 63: [child(kevan_lannister, _EX1)]
# min depth: 2
# Nodes: 4
# Answers: 2
#
# 64: [ancestor(X, Y), male(X), mother(alannys_harlaw, Y), son(Y, alannys_harlaw)]
# min depth: 2
# Nodes: 100252
# Answers: 135
#
# 65: [descendant(maron_greyjoy, alannys_harlaw)]
# min depth: 3
# Nodes: 13089
# Answers: 1
#
# 66: [descendant(_EX4, X)]
# min depth: 3
# Nodes: 41913
# Answers: 180
#
# 67: [daughter(X, elia_martell)]
# min depth: 3
# Nodes: 35
# Answers: 1
#
# 68: [father(X, Y), child(Y, X), child(X, Z), daughter(Y, X), ancestor(Z, Y)]
# min depth: 3
# Nodes: 160
# Answers: 54
#
# 69: [child(Z, _EX6)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 70: [mother(rhaella_targaryen, _EX0)]
# min depth: 3
# Nodes: 8
# Answers: 3
#
# 71: [parent(unknown_mother_targaryen, X), child(X, unknown_mother_targaryen), son(X, unknown_mother_targaryen)]
# min depth: 1
# Nodes: 5
# Answers: 4
#
# 72: [son(bran_stark, X), parent(X, bran_stark)]
# min depth: 3
# Nodes: 6
# Answers: 2
#
# 73: [who_loved_daenerys_and_was_corresponded(_EX4)]
# min depth: 3
# Nodes: 10
# Answers: 4
#
# 74: [child(Z, unknown_mother_sand_2)]
# min depth: 2
# Nodes: 3
# Answers: 1
#
# 75: [father(oberyn_martell, _EX0)]
# min depth: 3
# Nodes: 8
# Answers: 5
#
# 76: [ancestor(_EX5, myrcella_lannister)]
# Restart...
# min depth: 2
# Nodes: 61337
# Answers: 20
#
# 77: [child(X, unknown_mother_sand_2), daughter(X, Y), father(Y, X)]
# min depth: 2
# Nodes: 3
# Answers: 1
#
# 78: [son(_EX1, Y)]
# min depth: 3
# Nodes: 178
# Answers: 72
#
# 79: [ancestor(_EX6, _EX4)]
# min depth: 2
# Nodes: 100092
# Answers: 132
#
# 80: [daughter(X, Y), mother(selyse_baratheon, X), mother(cassana_estermont, Y)]
# min depth: 3
# Nodes: 62
# Answers: 28
#
# 81: [ancestor(X, jaime_lannister), parent(tytos_lannister, X), ancestor(X, joffery_lannister), son(jaime_lannister, X)]
# min depth: 2
# Nodes: 100187
# Answers: 4
#
# 82: [descendant(Y, X), mother(X, Y), parent(X, Y), son(Y, doran_martell)]
# Restart...
# Restart...
# min depth: 3
# Nodes: 1273
# Answers: 190
#
# 83: [ancestor(_EX6, Z)]
# min depth: 4
# Nodes: 100107
# Answers: 23
#
# 84: [child(_EX4, unknown_father_greyjoy)]
# min depth: 2
# Nodes: 5
# Answers: 3
#
# 85: [descendant(_EX5, _EX1)]
# min depth: 3
# Nodes: 45667
# Answers: 209
#
# 86: [father(_EX5, tyene_sand)]
# min depth: 3
# Nodes: 50
# Answers: 1
#
# 87: [child(_EX2, _EX3)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 88: [ancestor(_EX1, aegon_targaryen)]
# min depth: 4
# Nodes: 562
# Answers: 24
#
# 89: [son(_EX2, X)]
# min depth: 3
# Nodes: 178
# Answers: 72
#
# 90: [ancestor(mace_tyrell, margaery_tyrell)]
# Restart...
# min depth: 2
# Nodes: 5653
# Answers: 1
#
# 91: [father(Z, _EX6)]
# min depth: 3
# Nodes: 103
# Answers: 54
#
# 92: [status(X, Y), status(lewyn_martell, Y)]
# min depth: 1
# Nodes: 80
# Answers: 79
#
# 93: [son(X, tywin_lannister), child(X, tywin_lannister)]
# min depth: 3
# Nodes: 51
# Answers: 2
#
# 94: [descendant(_EX5, rickard_stark)]
# min depth: 3
# Nodes: 3942
# Answers: 13
#
# 95: [son(X, Y), father(Y, X), son(Y, unknown_mother_greyjoy)]
# min depth: 3
# Nodes: 178
# Answers: 72
#
# 96: [daughter(_EX0, elia_martell)]
# min depth: 3
# Nodes: 5
# Answers: 1
#
# 97: [child(shireen_baratheon, stannis_baratheon)]
# min depth: 2
# Nodes: 3
# Answers: 1
#
# 98: [mother(Y, X), child(X, mace_tyrell), mother(Y, margaery_tyrell)]
# min depth: 3
# Nodes: 155
# Answers: 49
#
# 99: [ancestor(Z, _EX1)]
# min depth: 2
# Nodes: 100147
# Answers: 152
#
# 100: [ancestor(_EX4, _EX1)]
# min depth: 2
# Nodes: 100161
# Answers: 136
#
# Before removing duplicates: 1547757 examples
# After removing duplicates: 22557 examples
# Replicating pos examples 2 times
# pos len=17613, neg len=17613

# %% [markdown]
# Train the scoring model. This step will usually take several minutes, especially if you are not using a GPU (for the gameofthrones KB, it takes about 30 minutes on CPU).
#
# Creates a file:
# * uni_mr_model.pt - Contains the weights for the learned scoring model

# %%
import sys
# !{sys.executable} nnreasoner.py --embed_type unification
# Out:
# States from vocab: vocab
# Num predicates: 45
# Max arity: 2
# Num constants: 106
# Num variables: 10
#
# Training unification
# Embed size: 50
# Reading examples from mr_train_examples.csv
# Parsing examples...
# Generating embeddings...
# Embedding input size: 277
#  [███████████████] 35225/35225 Prepping examples
# Loaded data...
# Using cuda device
# 0	0.59342 (-)
# 50	0.48359 (-0.0018)
# 100	0.44537 (-0.0013)
# 150	0.43714 (-0.0011)
# 200	0.42043 (-0.0009)
# 250	0.42457 (-0.0006)
# 300	0.38703 (-0.0006)
# 350	0.38342 (-0.0005)
# 400	0.41004 (-0.0004)
# 450	0.48414 (-8.6362)
# 500	0.47525 (-0.0002)
# 550	0.45799 (-0.0002)
# 600	0.43578 (-0.0002)
# 650	0.41809 (-0.0002)
# 700	0.38553 (-0.0002)
# 750	0.36814 (-0.0002)
# 800	0.36807 (-0.0002)
# 850	0.37815 (-0.0002)
# 900	0.35796 (-0.0002)
# 950	0.35322 (-0.0002)
# 1000	0.34852 (-0.0002)
# 1050	0.34447 (-0.0002)
# 1100	0.35375 (-0.0002)
# 1150	0.35372 (-0.0002)
# 1200	0.35258 (-0.0001)
# 1250	0.34996 (-0.0001)
# 1300	0.35024 (-0.0001)
# 1350	0.34800 (-0.0001)
# 1400	0.34850 (-0.0001)
# 1450	0.34504 (-0.0001)
# 1500	0.34622 (-0.0001)
# 1550	0.34459 (-0.0001)
# 1600	0.34081 (-0.0001)
# 1649	0.33344 (-0.0001)
# Saved training loss figure.

# %%
img = plt.imread('guided_loss-unification45-106-2-50.png')
plt. imshow(img)

# %% [markdown]
# Evaluate the scoring model by running evaluate.py. We compare the standard backward-chaining algorithm (-s) with the one that uses our learned scoring model (-u).
#
# The output lists each query, and then provides a line that gives information about query execution. These are: number of nodes explored in the tree, depth of the solution, execution time in seconds, and the speed of exploring the tree (nodes per second).
#
# The names of the files produced depend on the KB used and the options selected. The code below produces the files:
#
# * std-45-106-2-50.csv - A CSV file with query results for the standard backward-chaining algorithm
# * ming-45-106-2-50.csv - A CSV file with query results for the learned reasoner. ming stands for "min scoring goal" and is the default strategy for deciding how to make use of the scores
#
# If you use a different knowledge base, you will likely get different file names that depend on the features of that KB's vocabulary.

# %%
import sys
# !{sys.executable}  evaluate.py --kb gameofthrones.txt -s
# !{sys.executable} evaluate.py --kb gameofthrones.txt -u
# Out:
# using cuda device
# STANDARD
#
# Query 1: [ancestor(Y, X), descendant(X, tywin_lannister), mother(Y, kevan_lannister)]
# 9489 :: 10 - 00:00:01 (8095 nps)
#
# Query 2: [child(kevan_lannister, Z)]
# 3 :: 2 - 00:00:00 (3882 nps)
#
# Query 3: [ancestor(X, tyrion_lannister)]
# 3 :: 2 - 00:00:00 (4017 nps)
#
# Query 4: [status(X, alive)]
# 2 :: 1 - 00:00:00 (3309 nps)
#
# Query 5: [child(Z, _EX5)]
# 3 :: 2 - 00:00:00 (1808 nps)
#
# Query 6: [child(tywin_lannister, _EX4)]
# 3 :: 2 - 00:00:00 (4155 nps)
#
# Query 7: [son(X, Y), parent(X, margaery_tyrell), parent(Y, X), ancestor(Y, X), female(Y)]
# 107 :: 8 - 00:00:00 (3156 nps)
#
# Query 8: [ancestor(aegon_v_targaryen, X), ancestor(X, aegon_targaryen), ancestor(X, Y), descendant(Y, X)]
# 108 :: 11 - 00:00:00 (7091 nps)
#
# Query 9: [son(X, balon_greyjoy), ancestor(Y, X), ancestor(Y, Z), status(Z, alive)]
# 34 :: 8 - 00:00:00 (1683 nps)
#
# Query 10: [child(X, rhaegar_targaryen), descendant(X, unknown_mother_targaryen)]
# 14 :: 9 - 00:00:00 (1019 nps)
#
# Query 11: [child(_EX6, _EX3)]
# 3 :: 2 - 00:00:00 (2521 nps)
#
# Query 12: [descendant(X, _EX6)]
# 4 :: 3 - 00:00:00 (2726 nps)
#
# Query 13: [descendant(_EX3, Z)]
# 4 :: 3 - 00:00:00 (3114 nps)
#
# Query 14: [ancestor(X, Y), descendant(lancel_lannister, X), descendant(Y, tywin_lannister), ancestor(X, tywin_lannister)]
# 7988 :: 14 - 00:00:00 (26674 nps)
#
# Query 15: [ancestor(rickard_stark, Y)]
# 3 :: 2 - 00:00:00 (3040 nps)
#
# Query 16: [descendant(lyanna_stark, rickard_stark)]
# 4 :: 3 - 00:00:00 (5386 nps)
#
# Query 17: [who_killed_dragons(euron_greyjoy)]
# 4 :: 3 - 00:00:00 (23150 nps)
#
# Query 18: [child(X, aerys_targaryen), betray(varys, X)]
# 6 :: 3 - 00:00:00 (5540 nps)
#
# Query 19: [mother(Z, theon_greyjoy)]
# 4 :: 3 - 00:00:00 (1299 nps)
#
# Query 20: [who_loved_daenerys_and_was_corresponded(X), who_loved_daenerys(X)]
# 6 :: 5 - 00:00:00 (16291 nps)
#
# Query 21: [son(aerys_targaryen, X), ancestor(X, daenerys_targaryen)]
# 9 :: 7 - 00:00:00 (3751 nps)
#
# Query 22: [father(jaime_lannister, X), ancestor(tytos_lannister, X)]
# 14 :: 9 - 00:00:00 (3624 nps)
#
# Query 23: [ancestor(_EX6, _EX3)]
# 3 :: 2 - 00:00:00 (1798 nps)
#
# Query 24: [descendant(_EX6, X)]
# 4 :: 3 - 00:00:00 (3293 nps)
#
# Query 25: [status(X, dead), child(X, kevan_lannister)]
# 46 :: 3 - 00:00:00 (1778 nps)
#
# Query 26: [ancestor(Z, _EX1)]
# 3 :: 2 - 00:00:00 (1223 nps)
#
# Query 27: [descendant(X, unknown_mother_sand_2), father(oberyn_martell, X)]
# 7 :: 6 - 00:00:00 (3785 nps)
#
# Query 28: [ancestor(_EX3, maron_greyjoy)]
# 3 :: 2 - 00:00:00 (4031 nps)
#
# Query 29: [parent(X, Z), child(theon_greyjoy, X), descendant(Y, X), son(Y, balon_greyjoy), father(balon_greyjoy, Z)]
# 149 :: 12 - 00:00:00 (6416 nps)
#
# Query 30: [ancestor(_EX4, _EX6)]
# 3 :: 2 - 00:00:00 (1356 nps)
#
# Query 31: [descendant(X, Y), daughter(X, Z), child(X, Y), ancestor(Z, X), child(Z, olenna_tyrell)]
# 457 :: 12 - 00:00:00 (14020 nps)
#
# Query 32: [ancestor(rickard_stark, _EX1)]
# 3 :: 2 - 00:00:00 (3134 nps)
#
# Query 33: [child(X, alerie_hightower), descendant(X, Y), status(Y, dead), ancestor(Y, X)]
# 9 :: 8 - 00:00:00 (3413 nps)
#
# Query 34: [son(Z, X), son(Y, X), son(Y, unknown_mother_stark), male(Z)]
# 476 :: 10 - 00:00:00 (2074 nps)
#
# Query 35: [daughter(_EX4, Y)]
# 6 :: 3 - 00:00:00 (2705 nps)
#
# Query 36: [ancestor(Z, _EX0)]
# 3 :: 2 - 00:00:00 (1703 nps)
#
# Query 37: [ancestor(Z, tyrion_lannister)]
# 3 :: 2 - 00:00:00 (4085 nps)
#
# Query 38: [mother(X, doran_martell), ancestor(X, Y), descendant(Y, unknown_mother_sand_2), child(Y, unknown_mother_sand_2)]
# 294 :: 12 - 00:00:00 (5987 nps)
#
# Query 39: [child(mace_tyrell, _EX3)]
# 3 :: 2 - 00:00:00 (3921 nps)
#
# Query 40: [child(robb_stark, Y)]
# 3 :: 2 - 00:00:00 (4096 nps)
#
# Query 41: [mother(rhaella_targaryen, _EX3)]
# 4 :: 3 - 00:00:00 (3589 nps)
#
# Query 42: [child(X, _EX1)]
# 3 :: 2 - 00:00:00 (1422 nps)
#
# Query 43: [father(_EX5, _EX1)]
# 5 :: 3 - 00:00:00 (2367 nps)
#
# Query 44: [father(X, bran_stark), mother(Y, X), daughter(lyanna_stark, Y)]
# 50 :: 9 - 00:00:00 (1386 nps)
#
# Query 45: [status(X, Y), status(robb_stark, Y)]
# 3 :: 2 - 00:00:00 (1450 nps)
#
# Query 46: [descendant(tyrion_lannister, _EX5)]
# 4 :: 3 - 00:00:00 (5053 nps)
#
# Query 47: [parent(Y, X), descendant(X, unknown_mother_stark), descendant(arya_stark, Y), child(arya_stark, Y)]
# 829 :: 11 - 00:00:00 (26536 nps)
#
# Query 48: [ancestor(Y, _EX2)]
# 3 :: 2 - 00:00:00 (2071 nps)
#
# Query 49: [descendant(martyn_lannister, X), status(X, Y), status(walder_frey, Y)]
# 6 :: 5 - 00:00:00 (3089 nps)
#
# Query 50: [ancestor(balon_greyjoy, _EX0)]
# 3 :: 2 - 00:00:00 (3117 nps)
#
# Query 51: [child(_EX6, mace_tyrell)]
# 3 :: 2 - 00:00:00 (3326 nps)
#
# Query 52: [son(_EX2, rhaegar_targaryen)]
# 4 :: 3 - 00:00:00 (3760 nps)
#
# Query 53: [descendant(tommen_lannister, X), descendant(myrcella_lannister, X), descendant(joffery_lannister, X), child(kevan_lannister, X)]
# Query failed!!!
# 994 :: 0 - 00:00:00 (12375 nps)
#
# Query 54: [child(duncan_targaryen, _EX0)]
# 3 :: 2 - 00:00:00 (3596 nps)
#
# Query 55: [descendant(X, unknown_mother_greyjoy), ancestor(Y, X), ancestor(Y, balon_greyjoy), ancestor(Y, euron_greyjoy), child(X, unknown_mother_greyjoy)]
# 12 :: 11 - 00:00:00 (3305 nps)
#
# Query 56: [descendant(_EX0, tytos_lannister)]
# 4 :: 3 - 00:00:00 (4104 nps)
#
# Query 57: [child(_EX4, Z)]
# 3 :: 2 - 00:00:00 (14 nps)
#
# Query 58: [mother(X, Y), parent(X, Y), son(Y, X), descendant(Y, Z), mother(Z, tywin_lannister)]
# 726 :: 15 - 00:00:00 (7297 nps)
#
# Query 59: [ancestor(_EX3, renly_baratheon)]
# 3 :: 2 - 00:00:00 (3685 nps)
#
# Query 60: [ancestor(joanna_lannister, _EX5)]
# 3 :: 2 - 00:00:00 (3094 nps)
#
# Query 61: [who_taken_away_the_mad_queen(drogon)]
# 6 :: 5 - 00:00:00 (34179 nps)
#
# Query 62: [child(X, unknown_mother_sand_1), ancestor(unknown_mother_sand_1, X), descendant(X, unknown_mother_sand_1), descendant(X, lewyn_martell)]
# 14 :: 12 - 00:00:00 (2994 nps)
#
# Query 63: [descendant(X, luthor_tyrell), parent(Y, X), child(loras_tyrell, Y)]
# 36 :: 8 - 00:00:00 (3705 nps)
#
# Query 64: [child(_EX2, _EX4)]
# 3 :: 2 - 00:00:00 (1658 nps)
#
# Query 65: [descendant(X, aegon_v_targaryen), child(X, aerys_targaryen)]
# 50 :: 7 - 00:00:00 (3933 nps)
#
# Query 66: [descendant(X, Z), ancestor(Y, X), parent(Y, nymeria_sand), ancestor(Z, nymeria_sand), descendant(doran_martell, Z)]
# 9638 :: 15 - 00:00:00 (26354 nps)
#
# Query 67: [father(X, Y), parent(X, Y), child(arya_stark, X), descendant(Y, rickard_stark)]
# 60 :: 11 - 00:00:00 (2287 nps)
#
# Query 68: [child(viserys_targaryen, _EX5)]
# 3 :: 2 - 00:00:00 (4037 nps)
#
# Query 69: [parent(X, renly_baratheon), status(X, dead)]
# 3 :: 2 - 00:00:00 (2323 nps)
#
# Query 70: [ancestor(X, _EX0)]
# 3 :: 2 - 00:00:00 (1015 nps)
#
# Query 71: [descendant(nymeria_sand, _EX6)]
# 4 :: 3 - 00:00:00 (4785 nps)
#
# Query 72: [ancestor(cersei_lannister, X), status(X, dead), father(jaime_lannister, X), daughter(X, cersei_lannister)]
# 16 :: 9 - 00:00:00 (3817 nps)
#
# Query 73: [daughter(rhaenys_targaryen, X), parent(X, aegon_targaryen)]
# 5 :: 4 - 00:00:00 (3148 nps)
#
# Query 74: [child(X, Y), mother(Y, X), son(stannis_baratheon, Y)]
# 385 :: 8 - 00:00:00 (5519 nps)
#
# Query 75: [who_loved_daenerys_and_was_corresponded(Y)]
# 4 :: 3 - 00:00:00 (20275 nps)
#
# Query 76: [descendant(Z, kevan_lannister)]
# 4 :: 3 - 00:00:00 (4169 nps)
#
# Query 77: [ancestor(X, Y), parent(X, daeron_targaryen), child(Y, elia_martell)]
# 409 :: 9 - 00:00:00 (5989 nps)
#
# Query 78: [son(theon_greyjoy, Y)]
# 4 :: 3 - 00:00:00 (3557 nps)
#
# Query 79: [son(_EX5, unknown_mother_martell)]
# 13 :: 3 - 00:00:00 (2442 nps)
#
# Query 80: [mother(X, Y), parent(joanna_lannister, X), ancestor(tywin_lannister, Y), child(X, joanna_lannister), descendant(Y, jaime_lannister)]
# 34 :: 13 - 00:00:00 (5027 nps)
#
# Query 81: [ancestor(rickard_stark, _EX5)]
# 3 :: 2 - 00:00:00 (3175 nps)
#
# Query 82: [descendant(X, unknown_mother_greyjoy), son(X, unknown_mother_greyjoy)]
# 7 :: 6 - 00:00:00 (17400 nps)
#
# Query 83: [ancestor(balon_greyjoy, _EX4)]
# 3 :: 2 - 00:00:00 (3183 nps)
#
# Query 84: [parent(X, duncan_targaryen), descendant(daenerys_targaryen, X), child(aerys_targaryen, X), descendant(aerys_targaryen, X)]
# 13 :: 11 - 00:00:00 (3632 nps)
#
# Query 85: [child(X, unknown_mother_lannister), parent(X, Y), father(X, lancel_lannister), son(X, unknown_mother_lannister), child(Y, X)]
# 22 :: 11 - 00:00:00 (3546 nps)
#
# Query 86: [descendant(_EX2, X)]
# 4 :: 3 - 00:00:00 (1623 nps)
#
# Query 87: [ancestor(X, Y), ancestor(X, lancel_lannister), parent(Y, tyrion_lannister), ancestor(X, martyn_lannister), descendant(cersei_lannister, X)]
# Query failed!!!
# 13074 :: 0 - 00:00:00 (22678 nps)
#
# Query 88: [ancestor(_EX4, myrcella_lannister)]
# 3 :: 2 - 00:00:00 (3676 nps)
#
# Query 89: [child(X, rhaegar_targaryen), child(X, elia_martell), daughter(X, rhaegar_targaryen), status(X, dead)]
# 9 :: 8 - 00:00:00 (5541 nps)
#
# Query 90: [ancestor(eddard_stark, Y)]
# 3 :: 2 - 00:00:00 (2971 nps)
#
# Query 91: [son(X, alannys_harlaw), male(X), child(X, balon_greyjoy)]
# 30 :: 6 - 00:00:00 (1334 nps)
#
# Query 92: [status(X, dead)]
# 2 :: 1 - 00:00:00 (23648 nps)
#
# Query 93: [descendant(_EX3, Z)]
# 4 :: 3 - 00:00:00 (43511 nps)
#
# Query 94: [daughter(daenerys_targaryen, X), child(X, Y), descendant(daenerys_targaryen, X), son(Z, Y), descendant(Z, aegon_v_targaryen)]
# 18 :: 14 - 00:00:00 (1892 nps)
#
# Query 95: [child(X, _EX6)]
# 3 :: 2 - 00:00:00 (2318 nps)
#
# Query 96: [descendant(_EX4, _EX2)]
# 4 :: 3 - 00:00:00 (2472 nps)
#
# Query 97: [female(X), ancestor(Y, X), child(balon_greyjoy, Y)]
# 1668 :: 7 - 00:00:00 (5316 nps)
#
# Query 98: [ancestor(aerys_targaryen, rhaenys_targaryen)]
# 6 :: 4 - 00:00:00 (4059 nps)
#
# Query 99: [mother(unknown_mother_stark, X), descendant(X, rickard_stark)]
# 7 :: 6 - 00:00:00 (3643 nps)
#
# Query 100: [mother(X, Y), female(X), descendant(Y, X), parent(X, Y), descendant(Y, oberyn_martell)]
# 1582 :: 11 - 00:00:00 (17664 nps)
#
# std: 491.14 nodes/query
# 2 queries failed
# Time to run all queries: 4.059926805000009
# using cuda device
# UNITY: ming
# 	Embedding Model: rKB_model.pth
# 	Scoring Model: uni_mr_model.pt
#
# 	Control: mingoal
# 	Rule Eval: Max Rule
# Learned Embedding: Network using cuda
# Query 1: [ancestor(Y, X), descendant(X, tywin_lannister), mother(Y, kevan_lannister)]
# Query failed!!!
# 1000000 :: 0 - 00:00:48 (20749 nps)
#
# Query 2: [child(kevan_lannister, Z)]
# 3 :: 2 - 00:00:00 (642 nps)
#
# Query 3: [ancestor(X, tyrion_lannister)]
# 3 :: 2 - 00:00:00 (674 nps)
#
# Query 4: [status(X, alive)]
# 2 :: 1 - 00:00:00 (167 nps)
#
# Query 5: [child(Z, _EX5)]
# 3 :: 2 - 00:00:00 (40 nps)
#
# Query 6: [child(tywin_lannister, _EX4)]
# 3 :: 2 - 00:00:00 (858 nps)
#
# Query 7: [son(X, Y), parent(X, margaery_tyrell), parent(Y, X), ancestor(Y, X), female(Y)]
# Query failed!!!
# 1000000 :: 0 - 00:00:44 (22410 nps)
#
# Query 8: [ancestor(aegon_v_targaryen, X), ancestor(X, aegon_targaryen), ancestor(X, Y), descendant(Y, X)]
# 325819 :: 11 - 00:00:25 (12649 nps)
#
# Query 9: [son(X, balon_greyjoy), ancestor(Y, X), ancestor(Y, Z), status(Z, alive)]
# 183 :: 8 - 00:00:00 (383 nps)
#
# Query 10: [child(X, rhaegar_targaryen), descendant(X, unknown_mother_targaryen)]
# Query failed!!!
# 1000000 :: 0 - 00:00:34 (28862 nps)
#
# Query 11: [child(_EX6, _EX3)]
# 3 :: 2 - 00:00:00 (39 nps)
#
# Query 12: [descendant(X, _EX6)]
# 4 :: 3 - 00:00:00 (40 nps)
#
# Query 13: [descendant(_EX3, Z)]
# 4 :: 3 - 00:00:00 (51 nps)
#
# Query 14: [ancestor(X, Y), descendant(lancel_lannister, X), descendant(Y, tywin_lannister), ancestor(X, tywin_lannister)]
# 1949 :: 13 - 00:00:05 (374 nps)
#
# Query 15: [ancestor(rickard_stark, Y)]
# 3 :: 2 - 00:00:00 (478 nps)
#
# Query 16: [descendant(lyanna_stark, rickard_stark)]
# 4 :: 3 - 00:00:00 (826 nps)
#
# Query 17: [who_killed_dragons(euron_greyjoy)]
# 4 :: 3 - 00:00:00 (805 nps)
#
# Query 18: [child(X, aerys_targaryen), betray(varys, X)]
# 4 :: 3 - 00:00:00 (585 nps)
#
# Query 19: [mother(Z, theon_greyjoy)]
# 4 :: 3 - 00:00:00 (158 nps)
#
# Query 20: [who_loved_daenerys_and_was_corresponded(X), who_loved_daenerys(X)]
# 5 :: 4 - 00:00:00 (295 nps)
#
# Query 21: [son(aerys_targaryen, X), ancestor(X, daenerys_targaryen)]
# 13 :: 6 - 00:00:00 (52 nps)
#
# Query 22: [father(jaime_lannister, X), ancestor(tytos_lannister, X)]
# 38 :: 9 - 00:00:00 (88 nps)
#
# Query 23: [ancestor(_EX6, _EX3)]
# 3 :: 2 - 00:00:00 (39 nps)
#
# Query 24: [descendant(_EX6, X)]
# 4 :: 3 - 00:00:00 (52 nps)
#
# Query 25: [status(X, dead), child(X, kevan_lannister)]
# 4 :: 3 - 00:00:00 (42 nps)
#
# Query 26: [ancestor(Z, _EX1)]
# 3 :: 2 - 00:00:00 (40 nps)
#
# Query 27: [descendant(X, unknown_mother_sand_2), father(oberyn_martell, X)]
# 7 :: 6 - 00:00:00 (528 nps)
#
# Query 28: [ancestor(_EX3, maron_greyjoy)]
# Query failed!!!
# 1000000 :: 0 - 00:06:57 (2396 nps)
#
# Query 29: [parent(X, Z), child(theon_greyjoy, X), descendant(Y, X), son(Y, balon_greyjoy), father(balon_greyjoy, Z)]
# 64 :: 12 - 00:00:01 (63 nps)
#
# Query 30: [ancestor(_EX4, _EX6)]
# 3 :: 2 - 00:00:00 (18 nps)
#
# Query 31: [descendant(X, Y), daughter(X, Z), child(X, Y), ancestor(Z, X), child(Z, olenna_tyrell)]
# 173 :: 11 - 00:00:01 (123 nps)
#
# Query 32: [ancestor(rickard_stark, _EX1)]
# 3 :: 2 - 00:00:00 (46 nps)
#
# Query 33: [child(X, alerie_hightower), descendant(X, Y), status(Y, dead), ancestor(Y, X)]
# 50 :: 7 - 00:00:00 (59 nps)
#
# Query 34: [son(Z, X), son(Y, X), son(Y, unknown_mother_stark), male(Z)]
# 152 :: 7 - 00:00:00 (286 nps)
#
# Query 35: [daughter(_EX4, Y)]
# 4 :: 3 - 00:00:00 (19 nps)
#
# Query 36: [ancestor(Z, _EX0)]
# 3 :: 2 - 00:00:00 (19 nps)
#
# Query 37: [ancestor(Z, tyrion_lannister)]
# 6 :: 4 - 00:00:00 (6 nps)
#
# Query 38: [mother(X, doran_martell), ancestor(X, Y), descendant(Y, unknown_mother_sand_2), child(Y, unknown_mother_sand_2)]
# Query failed!!!
# 1000000 :: 0 - 00:01:09 (14323 nps)
#
# Query 39: [child(mace_tyrell, _EX3)]
# 3 :: 2 - 00:00:00 (52 nps)
#
# Query 40: [child(robb_stark, Y)]
# 3 :: 2 - 00:00:00 (51 nps)
#
# Query 41: [mother(rhaella_targaryen, _EX3)]
# 4 :: 3 - 00:00:00 (129 nps)
#
# Query 42: [child(X, _EX1)]
# 3 :: 2 - 00:00:00 (37 nps)
#
# Query 43: [father(_EX5, _EX1)]
# 8 :: 3 - 00:00:00 (71 nps)
#
# Query 44: [father(X, bran_stark), mother(Y, X), daughter(lyanna_stark, Y)]
# 10 :: 9 - 00:00:00 (70 nps)
#
# Query 45: [status(X, Y), status(robb_stark, Y)]
# 3 :: 2 - 00:00:00 (14 nps)
#
# Query 46: [descendant(tyrion_lannister, _EX5)]
# 4 :: 3 - 00:00:00 (705 nps)
#
# Query 47: [parent(Y, X), descendant(X, unknown_mother_stark), descendant(arya_stark, Y), child(arya_stark, Y)]
# 18 :: 11 - 00:00:00 (36 nps)
#
# Query 48: [ancestor(Y, _EX2)]
# 3 :: 2 - 00:00:00 (14 nps)
#
# Query 49: [descendant(martyn_lannister, X), status(X, Y), status(walder_frey, Y)]
# 6 :: 5 - 00:00:00 (10 nps)
#
# Query 50: [ancestor(balon_greyjoy, _EX0)]
# 3 :: 2 - 00:00:00 (477 nps)
#
# Query 51: [child(_EX6, mace_tyrell)]
# 3 :: 2 - 00:00:00 (822 nps)
#
# Query 52: [son(_EX2, rhaegar_targaryen)]
# 4 :: 3 - 00:00:00 (104 nps)
#
# Query 53: [descendant(tommen_lannister, X), descendant(myrcella_lannister, X), descendant(joffery_lannister, X), child(kevan_lannister, X)]
# Query failed!!!
# 960503 :: 0 - 00:01:53 (8457 nps)
#
# Query 54: [child(duncan_targaryen, _EX0)]
# 3 :: 2 - 00:00:00 (814 nps)
#
# Query 55: [descendant(X, unknown_mother_greyjoy), ancestor(Y, X), ancestor(Y, balon_greyjoy), ancestor(Y, euron_greyjoy), child(X, unknown_mother_greyjoy)]
# 12 :: 11 - 00:00:00 (28 nps)
#
# Query 56: [descendant(_EX0, tytos_lannister)]
# 4 :: 3 - 00:00:00 (656 nps)
#
# Query 57: [child(_EX4, Z)]
# 3 :: 2 - 00:00:00 (39 nps)
#
# Query 58: [mother(X, Y), parent(X, Y), son(Y, X), descendant(Y, Z), mother(Z, tywin_lannister)]
# 66 :: 13 - 00:00:00 (77 nps)
#
# Query 59: [ancestor(_EX3, renly_baratheon)]
# 3 :: 2 - 00:00:00 (654 nps)
#
# Query 60: [ancestor(joanna_lannister, _EX5)]
# 3 :: 2 - 00:00:00 (550 nps)
#
# Query 61: [who_taken_away_the_mad_queen(drogon)]
# 6 :: 5 - 00:00:00 (667 nps)
#
# Query 62: [child(X, unknown_mother_sand_1), ancestor(unknown_mother_sand_1, X), descendant(X, unknown_mother_sand_1), descendant(X, lewyn_martell)]
# 19 :: 12 - 00:00:00 (148 nps)
#
# Query 63: [descendant(X, luthor_tyrell), parent(Y, X), child(loras_tyrell, Y)]
# 15 :: 8 - 00:00:00 (21 nps)
#
# Query 64: [child(_EX2, _EX4)]
# 3 :: 2 - 00:00:00 (20 nps)
#
# Query 65: [descendant(X, aegon_v_targaryen), child(X, aerys_targaryen)]
# 17 :: 7 - 00:00:00 (74 nps)
#
# Query 66: [descendant(X, Z), ancestor(Y, X), parent(Y, nymeria_sand), ancestor(Z, nymeria_sand), descendant(doran_martell, Z)]
# Query failed!!!
# 1000000 :: 0 - 00:02:33 (6500 nps)
#
# Query 67: [father(X, Y), parent(X, Y), child(arya_stark, X), descendant(Y, rickard_stark)]
# 540 :: 11 - 00:00:02 (196 nps)
#
# Query 68: [child(viserys_targaryen, _EX5)]
# 3 :: 2 - 00:00:00 (837 nps)
#
# Query 69: [parent(X, renly_baratheon), status(X, dead)]
# 3 :: 2 - 00:00:00 (61 nps)
#
# Query 70: [ancestor(X, _EX0)]
# 3 :: 2 - 00:00:00 (19 nps)
#
# Query 71: [descendant(nymeria_sand, _EX6)]
# 4 :: 3 - 00:00:00 (727 nps)
#
# Query 72: [ancestor(cersei_lannister, X), status(X, dead), father(jaime_lannister, X), daughter(X, cersei_lannister)]
# 9 :: 8 - 00:00:00 (25 nps)
#
# Query 73: [daughter(rhaenys_targaryen, X), parent(X, aegon_targaryen)]
# 5 :: 4 - 00:00:00 (595 nps)
#
# Query 74: [child(X, Y), mother(Y, X), son(stannis_baratheon, Y)]
# 9 :: 8 - 00:00:00 (388 nps)
#
# Query 75: [who_loved_daenerys_and_was_corresponded(Y)]
# 4 :: 3 - 00:00:00 (458 nps)
#
# Query 76: [descendant(Z, kevan_lannister)]
# 4 :: 3 - 00:00:00 (635 nps)
#
# Query 77: [ancestor(X, Y), parent(X, daeron_targaryen), child(Y, elia_martell)]
# 52 :: 9 - 00:00:00 (63 nps)
#
# Query 78: [son(theon_greyjoy, Y)]
# 4 :: 3 - 00:00:00 (685 nps)
#
# Query 79: [son(_EX5, unknown_mother_martell)]
# 5 :: 3 - 00:00:00 (44 nps)
#
# Query 80: [mother(X, Y), parent(joanna_lannister, X), ancestor(tywin_lannister, Y), child(X, joanna_lannister), descendant(Y, jaime_lannister)]
# 17068 :: 13 - 00:00:07 (2322 nps)
#
# Query 81: [ancestor(rickard_stark, _EX5)]
# 3 :: 2 - 00:00:00 (471 nps)
#
# Query 82: [descendant(X, unknown_mother_greyjoy), son(X, unknown_mother_greyjoy)]
# 7 :: 6 - 00:00:00 (465 nps)
#
# Query 83: [ancestor(balon_greyjoy, _EX4)]
# 3 :: 2 - 00:00:00 (500 nps)
#
# Query 84: [parent(X, duncan_targaryen), descendant(daenerys_targaryen, X), child(aerys_targaryen, X), descendant(aerys_targaryen, X)]
# 13 :: 11 - 00:00:00 (369 nps)
#
# Query 85: [child(X, unknown_mother_lannister), parent(X, Y), father(X, lancel_lannister), son(X, unknown_mother_lannister), child(Y, X)]
# 463 :: 11 - 00:00:02 (201 nps)
#
# Query 86: [descendant(_EX2, X)]
# 4 :: 3 - 00:00:00 (50 nps)
#
# Query 87: [ancestor(X, Y), ancestor(X, lancel_lannister), parent(Y, tyrion_lannister), ancestor(X, martyn_lannister), descendant(cersei_lannister, X)]
# Query failed!!!
# 17712 :: 0 - 00:00:21 (806 nps)
#
# Query 88: [ancestor(_EX4, myrcella_lannister)]
# 3 :: 2 - 00:00:00 (645 nps)
#
# Query 89: [child(X, rhaegar_targaryen), child(X, elia_martell), daughter(X, rhaegar_targaryen), status(X, dead)]
# 19 :: 8 - 00:00:00 (226 nps)
#
# Query 90: [ancestor(eddard_stark, Y)]
# 3 :: 2 - 00:00:00 (46 nps)
#
# Query 91: [son(X, alannys_harlaw), male(X), child(X, balon_greyjoy)]
# 10 :: 6 - 00:00:00 (124 nps)
#
# Query 92: [status(X, dead)]
# 2 :: 1 - 00:00:00 (18606 nps)
#
# Query 93: [descendant(_EX3, Z)]
# 4 :: 3 - 00:00:00 (20 nps)
#
# Query 94: [daughter(daenerys_targaryen, X), child(X, Y), descendant(daenerys_targaryen, X), son(Z, Y), descendant(Z, aegon_v_targaryen)]
# 15 :: 14 - 00:00:00 (44 nps)
#
# Query 95: [child(X, _EX6)]
# 3 :: 2 - 00:00:00 (38 nps)
#
# Query 96: [descendant(_EX4, _EX2)]
# 4 :: 3 - 00:00:00 (44 nps)
#
# Query 97: [female(X), ancestor(Y, X), child(balon_greyjoy, Y)]
# 642 :: 7 - 00:00:01 (495 nps)
#
# Query 98: [ancestor(aerys_targaryen, rhaenys_targaryen)]
# 6 :: 4 - 00:00:00 (28 nps)
#
# Query 99: [mother(unknown_mother_stark, X), descendant(X, rickard_stark)]
# 7 :: 6 - 00:00:00 (40 nps)
#
# Query 100: [mother(X, Y), female(X), descendant(Y, X), parent(X, Y), descendant(Y, oberyn_martell)]
# 14 :: 10 - 00:00:00 (144 nps)
#
# ming: 73259.12 nodes/query
# 8 queries failed
# Time to run all queries: 963.5093939879996

# %% [markdown]
# The results suggest only minor improvements for the gameofthrones KB: on average 3.75 vs. 4.39 node per query when I ran it. You may get different results due to the randomization of training and random selection of test queries. Larger, more complex KBs can see much larger improvements, sometimes an order of magnitude or more.
#
# The code below shows the first 10 lines of each query result file. A given line has:
# * query sequence number
# * configuration name
# * number of nodes explored
# * depth of solution (0 if no solution found)
# * did the system find a solution (true/false)
# * time in seconds
#
# You can import these files into a spreadsheet in order to create plots or summary statistics.

# %%
# !head std-45-106-2-50.csv
# !head ming-45-106-2-50.csv
# Out:
# query,std reasoner,std nodes explored,std min depth,success,time
# 1,std,9489,10,True,1.1721520510000012
# 2,std,3,2,True,0.0007726750000003335
# 3,std,3,2,True,0.0007467410000003838
# 4,std,2,1,True,0.0006042770000007636
# 5,std,3,2,True,0.0016587249999986398
# 6,std,3,2,True,0.0007219850000002026
# 7,std,107,8,True,0.033895118000000224
# 8,std,108,11,True,0.015230023999999176
# 9,std,34,8,True,0.020201654999999263
# query,ming reasoner,ming nodes explored,ming min depth,success,time
# 1,ming,1000000,0,False,48.193561389
# 2,ming,3,2,True,0.004669963000004884
# 3,ming,3,2,True,0.00445004099999835
# 4,ming,2,1,True,0.011944941000002984
# 5,ming,3,2,True,0.07431507299999396
# 6,ming,3,2,True,0.003495330000006902
# 7,ming,1000000,0,False,44.621351843999996
# 8,ming,325819,11,True,25.757056218999992
# 9,ming,183,8,True,0.4776613310000073
